# %% [markdown]
# # Cost function and Gradient descent

# %% [markdown]
# - Cost function is sum of all the errors which are present in the application which we have made
# - So cost function is something which we want to minimize , because we want to minimize the error which is present in our model
# - for ex. our cost function might be the sum of squared the error over the training set so in this case we will be reducing the sum of squared error so will have to reduce the error of the entire model which we have now
#
# - Gradient descent is method for finding the minimum of a function of multiple variables so we want to find out the minimum value of multiple varaiable so we can use gradient descent as tool to minimize cost function
#
# - why we need gradient descent

# %% [markdown]
# ** why we need gradient descent**

# %% [markdown]
# ![20.JPG](attachment:20.JPG)

# %% [markdown]
# let's say we have this data , we have this line which we ahve to create and we will find out several beta values for this
#
# one way could be , we can randomly be select
# some beta values and keep on trying again n again until we find a very low cost value
#
# so we will put a lot of beeta values and will compare different models which we have created and we will select teh model which wil have minimum cost value and based on that cost value which beeta value we have used we will use those values
#
# but this will not be feasible solution because what will happen is we can use it but we should have endless amount of time and a lot of patience and we can keep trying on a lot of beeta values and by using those beeta values at that point  when beeta values stop changing when we don't really have to modify the value to reduce the cost at that point we will be stopping and we will select those value .
# But it is not feasible solution so we will use gradient descent.

# %% [markdown]
# ![21.JPG](attachment:21.JPG)

# %% [markdown]
# - So when we are finding out teh cost value . So j(w) is nothing but the cost of the entire function . w is the weight or beeta values we can eitehr say beeta values or w it is same thing and j is nothing but a cost function sow e can say j(w)or c or f(x)
# - we will randomly select the values for beeta and based on the beeta we will select what will be the cost
# - as the beeta values changes the value of cost also changes  . So the cost will keep reducing initially and after a point of time when the cost will achieve the minimum vaue  after that when we again change the beeta value the cost will start increasing
# - So we want to find out optimal beeta values and thus we want to stop at that point of time when this cost is minimum

# %% [markdown]
# ![22.JPG](attachment:22.JPG)

# %% [markdown]
# - so here we have change in function and change in beeta values when we divide this function by the beeta values we get the theeta so we get the equation of tan(θ)
# - tan(θ) is nothing but slope of the line which is the change in the function w.r.t the change in beeta  value
# - $f/$b is the cost of function at any time and traingle beeta is the slight change in beeta value

# %% [markdown]
# - so if we change the beeta value cost value also change
# - and we can see the lsope is slowly and gradually decreasing
# - when we see at the top the slope is very high but after that the value of the slope is decreasing the value of the slope keep on decreasing as it reaches to the minimum point of the cost
# - so at one point the cost is minimal and slope is also minimal
# - so when we are changing the value of the weight or beeta their is one more scenario which would ocurre
# - intially the slope is high so we can change the value of beeta or weight faster but when we reach towards the minimum value what will happen is if we are making the chnge very faster then it may overshoot the minimum point
# - what we will have to do is we will ahve to reduce the change which we are making as we raech the minimum value
# - so now if we make changes very fast then there is chance of overshooting
# - now let's take look at other scenario if we are making changes very slowly than what will happen is that the value will take a lot of time to reach the minimum value so it will be slow that it might not even reach the global minimum value and might take  infinite amount of time to reach the minimum value so that is the reason why we will ahve to choose not very high value or not very small values we have to make sure that the value which we are selecting is a moderate value so that we can reach the global minimum

# %%
# let's try to formulate the equation

# %% [markdown]
# ![23.JPG](attachment:23.JPG)

# %% [markdown]
# ![24.JPG](attachment:24.JPG)

# %% [markdown]
# - So we can find out the cost value by finding out the beeta values because we already know the x values and the y value the only thing which we do not know here is the value of the beeta so we can find out the value of cost by putting different beeta values as y and x value are constant hence we woould try to find out beeta value such that cost is minimum

# %% [markdown]
# So the value of the cost will be

# %% [markdown]
# ![25.JPG](attachment:25.JPG)

# %% [markdown]
# update rule will be
#
# so when we are trying to update the weight or beeta value the update rule will be we will change the weight by w minus the change in cost w.r.t change in w which is
#
# So update rule will be w minus a learning rate into the change in cost w.r.t change in w
#
# learning rate is nothing but step

# %% [markdown]
# ![26.JPG](attachment:26.JPG)

# %% [markdown]
# ![27.JPG](attachment:27.JPG)

# %% [markdown]
# - after training the model is cahcked and validated on tetaing set

# %% [markdown]
# to prevent this we use cross validation method

# %% [markdown]
# ![28.JPG](attachment:28.JPG)

# %% [markdown]
# what is cross vlidation method
#
# instead of dividing the data into training and testing we divide the data into different folds now these folds could be any number of folds 5,7 or 15
# and based on these folds we allow each folds to be testing data at one iteration
# so in first iteration the first split , the first fold will become the testing data and all other folds will become the training data
#
# then in the next iteration the fold2  will become the testing data and all other folds will become the training data
#
# then in the next iteration the fold3  will become the testing data and all other folds will become the training data and so on
#
# and in last we will take average of performance of all models. thhis way the model will be able to learn from all the folds

# %% [markdown]
# ![29.JPG](attachment:29.JPG)

# %%
ss
