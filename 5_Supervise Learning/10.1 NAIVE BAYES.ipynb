# %% [markdown]
# # Naive bayes

# %% [markdown]
# ![134.JPG](attachment:134.JPG)

# %% [markdown]
# Let's undertand Some comcept of probability

# %% [markdown]
# ![135.JPG](attachment:135.JPG)

# %% [markdown]
# Here we have different fruits
#
# And out of these fruits if we want to get probability of apples or oranges or bananas
#
# p(apples) = number of apples /total number of fruits
#
# p(oranges ) = number of oranges  /total number of fruits
#
# p(bananas) = number of bananas /total number of fruits

# %% [markdown]
# ![136.JPG](attachment:136.JPG)

# %% [markdown]
# Now if we want to find out the probability of A , then the probability of getting a will be  Modulas of A divide by modulas of the universe
#
# if we want to find out the probability of B , then the probability of getting a will be  Modulas of B divide by modulas of the universe

# %% [markdown]
# ![137.JPG](attachment:137.JPG)

# %% [markdown]
# Now let's say that A and B actually intersect at AB So A and B have some common element named as AB then what will be the probability of getting AB
# It will be number of element in the AB divided by number of elemnts in the universe

# %% [markdown]
# ![138.JPG](attachment:138.JPG)

# %% [markdown]
# Now what is the probability of getting A that B is given TRUE so it will given by Number of elemnt in B divided by number of elemnt in B(because B is already true
#
# So we can derive p(B/A) by this

# %% [markdown]
# ![139.JPG](attachment:139.JPG)

# %% [markdown]
# ![140.JPG](attachment:140.JPG)
#
# # This is called as NAIVE bayes equation

# %% [markdown]
# ![141.JPG](attachment:141.JPG)

# %% [markdown]
# Let's take the loan data example now we want to find out the probability of person defaulting on loan or not and the condition are different value of the feature or attribute
#
# We have to find out if someone will default on loan or not on the basis of salry of the person, year of experience etc
#
# So in above image A is actually the feature which we want to predict and b1,B2,B3 are the x values thai is input feature
#
#
# If we have to find out the probability of multiple entities given on conditions if the different conditions are independent on each other then they could be said to be multiplied that is why we can write first formula as second formula

# %% [markdown]
# **Why this particular algorithm called as naive**
#
# The equation is bayes theorem but the algorithm is clled naive bayes because it assumes that all b1,b2,b3... are independent
# That is the reason why the first thing which we will do while creating this data for particular alogorithm , we remove all the correlation so that all the feature will be independent of each other

# %% [markdown]
# ![142.JPG](attachment:142.JPG)

# %% [markdown]
# In naive bayes we dont have to find out hyperparametr we just need to find out probabilities so that is easily done for a large dataset

# %% [markdown]
# ![143.JPG](attachment:143.JPG)

# %% [markdown]
# probability of c given x = p(c|x)
# from prior - what data we already have i.e p(c) occuring independetly, probability of x occuering independently etc

# %% [markdown]
# ![144.JPG](attachment:144.JPG)

# %% [markdown]
# Let's solve naive bayes problem first
#
# So we have this data

# %% [markdown]
# From above data we will craete frequency table that is number of occurence s of each value

# %% [markdown]
# ![145.JPG](attachment:145.JPG)

# %% [markdown]
# ![145.JPG](attachment:145.JPG)

# %% [markdown]
# ![148.JPG](attachment:148.JPG)

# %% [markdown]
# ![146.JPG](attachment:146.JPG)

# %% [markdown]
# ![147.JPG](attachment:147.JPG)
