# %% [markdown]
# # Support vector machine

# %% [markdown]
# ![149.JPG](attachment:149.JPG)

# %% [markdown]
# - It is one of the most popular used supervised ML algorithm
# - it is Used for both classification and regression but majorly it is used for the classification problem
# - The goal of the SVM is to create best line or decision boundry that can seggregate the n-dimensional into the classes
# - So we will be creating several lines between these two classes so that we are able to segregate them into different classes
# - Now these line will be helpful , as we can easily put the new data into the correct category using these line of seggregation
#
# - And the decision boundry which we have created is called as hyperplane
#
# - As in the below dig it is 2D data hence it is a line but whne it become the multidimensional data so in that case it will become hperplane
#
# - for SVM we choose the extream point or vectors that helps in creating the hyperplane
#
# - Now these extream cases are called support vectors
#
# - From the points which are nearest to other class these are called support vectors hence that is why these algorithm is called as support vector machine becuase it is using support vector to actually create hyperplane
#
# - SVM can be in linear form and non-linear form also

# %% [markdown]
# ![151.JPG](attachment:151.JPG)

# %% [markdown]
# Here we have data which is present in circular form
# So we can draw a single line to divide these data into TWO different class
#
# So what we will have to do is we will have to transform this data from two dimensional to three dimesnional
#
# So when we will look at this data into another dimesnion which we have added so here we have added dimension z
# So when we will look at this data w.r.t z dimension we can see that there is on eline of seperation between both of the classes
#
# So we will place a hyperplane between between both of these dimension or classes and that hyperplane will actually help us to create line of seggregation between the two classes
#
# So here we can see that transforming back to the xy plane : linear seperator become a circle

# %% [markdown]
# ![152.JPG](attachment:152.JPG)

# %% [markdown]
# SVM finds the most similar example between classes . Those will be the support vectors
#
#     So when we are looking at the particular class which is mango class , it tries to find out an apple , which is more like mango , so mango are usually yellow and longer in size , oval in size so we will look for an apple which is little bit yellowish in color and little longer than apple so those become the support vectors for the apple
#
#
#     Then we will look at teh apple class we will find out the mango which are little shorter in height , notvreally oval but circular in shape we found them as support vectors
#
#     Now between support vectors we draw the line these support vectors actually create a line of seggregation and between these two line we create a line which is having maximum margin from those two line and this margin is actually called as hyperplane

# %% [markdown]
# ![153.JPG](attachment:153.JPG)

# %% [markdown]
# Now here we can visualize the same thing
#
# So we have red and blue class
#
# So we hve found the ones  which is nearest to the blue one and called them as suppport vectors and the blue one which are nearest to red one are called the support vectors from the blue class
#
# and from that we have found out the maximum margin and maximizing the margin on the both direction we create a seperating hyperplane
#
# Once we have decided upon the support vectors we don't really need the other points from the data
#
# Now because we don't really need these other points from the data sow e don't really need to compare the others points while classifying
#
# All we need is the hyperplane once this hyperplane will be genearated whatever point we are looking at we will just compare the point with the hperplane and the directrion in which point lies from the hyperplane and decide what class it belongs to

# %% [markdown]
# ![154.JPG](attachment:154.JPG)
