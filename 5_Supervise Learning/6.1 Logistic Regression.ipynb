# %% [markdown]
# # Logistic Regression

# %% [markdown]
# - In Logistic regression we want to find out different classes
# - we want to find out if a particular value is yes or no
# - we waant to find out answer a problem if someone will by our product or not , whetehr someone should default on loan or not
# - So these are different type of problem which we will be solving on in case of logistic regression

# %% [markdown]
# **But why it is called as regression when we are not doing regression**

# %% [markdown]
# So regression means that we want to predict continuous values but in logistic regression we are doing classification that is we are trying to find out the answer to a class that is a categorical value
#
# so these type of problem should not be consider as regression problem but still we are saying it as regression problem this is not because it is regression algorithm it is classification algorithm only
#
# Because logistic regression is using regression internally in the calculations
# internally it is performing some kind of calculations that is the reason why we are calling it logistic regression
#
# Logistic regression is used for classification problem while for continuous problem or regression problem we use linear regression

# %% [markdown]
# ![33.JPG](attachment:33.JPG)

# %% [markdown]
# - In above digram we have data like one of the parameter or target value is 0 and one of the parameter or target value is 1
# - in this case if we try to apply a linear regression and we will try to put a line then the line will not be able to satisfy the problem because it is going digonally from the data
# - so we will not be able to make  decision with such kind of a line
# - this is the reason why we need logistic regression
# -------
# --------
# ---------
# - So what we will do we will create something like second digram
# - Now to raech this line or to reach this constructwhich will give  this kind of line which is able to map the data which is in class we will have to develop certain kind of understanding

# %% [markdown]
# ![34.JPG](attachment:34.JPG)

# %% [markdown]
# - So in this data we ask the children of various ages whether they are afraid of ghost or not
# - Now here we have different answer from these children
# - so the children of age four , there are four children who say yes one child who says no
# - so the children of age 5 , there are 3 children who say yes two child who says no
# - the children of age 6 , there are 2 children who say yes 3 child who says no
# - the children of age 7 , there are 1 children who say yes 3 child who says no
# --------------
# ------------------------
# ---------------------------
#
# - Now if someone will ask what might be the response for a child who's age is  seven then we can directly say that the response will be  nobecause here are the majority of the children of age seven have responded with no
# - here we found out the probability of it , we just simply check the probability of the response being no when the age is seven
# - So in this case we simply model with the probability of yes or no

# %% [markdown]
# ![35.JPG](attachment:35.JPG)

# %% [markdown]
# - here we are trying to predict different classes and we are not predicting continuous value so we are not solving regression problem
# - Now these classes should be of a type which are not possible together like someone can not pass or fail the exam at the same time  so we can not have something which occure together an animal can not be cat or do at the the same time it has to be either cat or dog
# - So now the probability of outcome being in favor of one class as finding out just hard class may not be enough to clarify the understanding
# - so if we find out the hard class that something is cat or dog that can not be feasible solution becuse we want to know more about
# - Let's say we want to predict that a person ahs heart disease or not for their particular age
# - Now if we sat for both ages 45 and 85 , that is not informative enough because a person whose age is 45 has less probability of having a heart disease in comparison to person whose age is 85
# - the person whose age is 85 is obbiously more at isk of having heart disease
# - so for solving such problem we actually need to know the probability of something happening
# - if we have cancer patients , a person who is testing for cancer and we simply ay that you have cancer or not that is not informative enough
# - we want to know what are the chances of someone cancere
# - so we need to know if there is 90% chance of someone having cancer or there is 10% chance of someone having cancer and based on that we can prescribe next step that what kind of test that person should have or what kind of medicine he should take
# - so these things will be dependent on the probability

# %% [markdown]
# # Difference between Linear regression and logisic regression

# %% [markdown]
# ![36.JPG](attachment:36.JPG)

# %% [markdown]
# ![37.JPG](attachment:37.JPG)

# %% [markdown]
# ![38.JPG](attachment:38.JPG)

# %% [markdown]
# ---------------------
# ---------------------------
# -----------------------------------------
#
# --------------------------------------------------

# %% [markdown]
# # Logistic Regression Mathematics

# %% [markdown]
# ![39.JPG](attachment:39.JPG)

# %% [markdown]
# - odds are the chanvces that something will happen , if we flip coin the odds are 50/50
# - Now if something strange will happen , people will often say what are the odds of that that mean's we can't belive that happened the odds were against it
# - ex- the odds in favor of rolling 2 or 3 on six sided dice is 1/5
# - Odds and probability are not same
# - odds range from 0-1 for against scenario while range from 1 -infinity for favourable case
#
# o(winning) = 5/3 in this favourable case a greater value is divided by smaller value then only it will be in favour of winning
#
# so it will be always be greater number divide by smaller number which means that it is always be greater than 1 so the value greater than 1 range from 1-infinty
#
# Now when we are discusiing about againstbthe scenario so for against scenario , it will always be smaller term divided by larger term
# so when this would be happen theen the value will be between zero to 1 and smaller number divided by larger number will always gives us a number which range from 0-1
# - So a value which is ranging from 0-1 is always present for against the scenario and for favorable scennario the odd will be range from 0-infinity

# %% [markdown]
# ![40.JPG](attachment:40.JPG)

# %% [markdown]
# We have this equation
#
# - probability oy y is equal to 1 given x is true is p

# %% [markdown]
# ![34.JPG](attachment:34.JPG)

# %% [markdown]
# here we have probability value p = b0+b1x1=b2x2+......+bnxn
#
# now this probability value ranging from 0-1  and this equation has range from -inf-+inf
#
# so what we can do is we can convert this equation into same range value by taking log of
# so if we take log of it then range mismatch issue will resolve

# %% [markdown]
# ![41.JPG](attachment:41.JPG)

# %% [markdown]
# ![42.JPG](attachment:42.JPG)

# %% [markdown]
# # Logistic Regression metrics

# %%
# Confusion matrix

# %% [markdown]
# ![43.JPG](attachment:43.JPG)

# %% [markdown]
# - Confusion matrix is the combination of actual value vs predicted value
# - it is cross table for predicted and the result that are real in nature
# - if we have predicted something negative then it may be true negative or false negative
# - if we have predicted something positive then it may be true positive or true negative
# --
# -----------------
# -------------------------------------
#
# - let's say we have predicted something to be positive and in real also it is positive so predicted and real value is matched this means that our prediction is true hence it is called True Positive
#
# - let's say we have predicted something to be positive and in real  it is negative  so predicted and real value is not matched this means that our prediction is false  hence it is called false  Positive
#
#
# - let's say we have predicted something to be negative  and in real also it is negative so predicted and real value is matched this means that our prediction is true hence it is called True negative
#
# - let's say we have predicted something to be negative  and in real  it is  not negative  so predicted and real value is not matched this means that our prediction is false  hence it is called false negative

# %% [markdown]
# ![44.JPG](attachment:44.JPG)

# %% [markdown]
# Next we have these different matrics

# %% [markdown]
# ![45.JPG](attachment:45.JPG)

# %% [markdown]
# ![46.JPG](attachment:46.JPG)

# %% [markdown]
# ![47.JPG](attachment:47.JPG)

# %% [markdown]
# ![48.JPG](attachment:48.JPG)

# %% [markdown]
# - it tells us how much a model is capable of distinguishing between different classes - - from AUC curve perspective from this curve we want to choose a particular score which has the most amount of area under this curve and when we have a thresold value
# - the higher the auc the better the model is at predicting

# %% [markdown]
# ![49.JPG](attachment:49.JPG)
