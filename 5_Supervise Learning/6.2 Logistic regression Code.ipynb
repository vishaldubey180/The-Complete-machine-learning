# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# here we will define report function also  S
#
# SO this report will genearte the report of the greadsearchcv or randomsearch cv and retrive the best model out of it

# %%
def report(results, n_top=3):
    for i in range(1,n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score']==1)
        for candidate in candidates:
            print('model with rank: {0}'.format(i))
            print('mean validationnscore : {0:.3f} (std: {1:.3f})'.format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print('parameters:{0}'.format(results['params'][candidate]))
            print("")

# %%
train = pd.read_csv('rg_train.csv')
test = pd.read_csv('rg_test.csv')

# %%
train.head()
# Out:
#    REF_NO children age_band   status     occupation occupation_partner  \
# 0    2148        1    45-50  Partner   Professional       Professional
# 1    8099        1    61-65  Partner        Retired            Retired
# 2    6611        3    31-35  Partner   Professional       Professional
# 3    1950     Zero    55-60  Partner   Professional       Professional
# 4   10857        2    51-55  Partner  Manual Worker      Manual Worker
#
#       home_status      family_income self_employed self_employed_partner  ...  \
# 0  Rent Privately           >=35,000           Yes                   Yes  ...
# 1        Own Home  <12,500, >=10,000            No                    No  ...
# 2        Own Home           >=35,000            No                    No  ...
# 3        Own Home           >=35,000            No                    No  ...
# 4        Own Home  <27,500, >=25,000           Yes                   Yes  ...
#
# ...

# %%
train.isnull().sum()
# Out:
# REF_NO                             0
# children                           0
# age_band                           0
# status                             0
# occupation                         0
# occupation_partner                 0
# home_status                        0
# family_income                      0
# self_employed                      0
# self_employed_partner              0
# year_last_moved                    0
# TVarea                             0
# post_code                          0
# post_area                          0
# Average.Credit.Card.Transaction    0
# Balance.Transfer                   0
# Term.Deposit                       0
# Life.Insurance                     0
# Medical.Insurance                  0
# Average.A.C.Balance                0
# Personal.Loan                      0
# Investment.in.Mutual.Fund          0
# Investment.Tax.Saving.Bond         0
# Home.Loan                          0
# Online.Purchase.Amount             0
# ...

# %% [markdown]
# As we can se that there is no null values

# %%
test
# Out:
#       REF_NO children age_band   status         occupation occupation_partner  \
# 0          9        1    36-40  Partner       Professional       Professional
# 1         13     Zero    61-65  Partner            Retired            Retired
# 2         18     Zero    26-30  Partner            Unknown       Professional
# 3         21        1    41-45  Partner  Secretarial/Admin      Manual Worker
# 4         26     Zero    26-30  Partner       Professional       Professional
# ...      ...      ...      ...      ...                ...                ...
# 2026   11496        2    41-45  Partner       Professional       Professional
# 2027   11503        1    45-50  Partner   Business Manager       Professional
# 2028   11509     Zero    61-65  Partner            Retired            Retired
# 2029   11511     Zero    55-60  Partner            Unknown          Housewife
# 2030   11514        2    41-45  Partner          Housewife       Professional
#
# ...

# %%
test.isnull().sum()
# Out:
# REF_NO                             0
# children                           0
# age_band                           0
# status                             0
# occupation                         0
# occupation_partner                 0
# home_status                        0
# family_income                      0
# self_employed                      0
# self_employed_partner              0
# year_last_moved                    0
# TVarea                             0
# post_code                          0
# post_area                          0
# Average.Credit.Card.Transaction    0
# Balance.Transfer                   0
# Term.Deposit                       0
# Life.Insurance                     0
# Medical.Insurance                  0
# Average.A.C.Balance                0
# Personal.Loan                      0
# Investment.in.Mutual.Fund          0
# Investment.Tax.Saving.Bond         0
# Home.Loan                          0
# Online.Purchase.Amount             0
# ...

# %% [markdown]
# here we have two type of data train  and test
#
# so we will train our model on training data and evaluate our model on testing data
#
#
# here whatever changes we will make into training dataset we have to amke in testing daatset also if changes are not same let's say we have trained our  model on training dataset on which we have performed all the  transformation and now we want to test on testing dataset if they are not sync in with each other then our model will not understand

# %% [markdown]
# so here we will combine our training and testing dataset we will do all the operation on that dataset and when we will done with transformation we will satisfied with transformation we will split the data into train and test

# %%
train.head()
# Out:
#    REF_NO children age_band   status     occupation occupation_partner  \
# 0    2148        1    45-50  Partner   Professional       Professional
# 1    8099        1    61-65  Partner        Retired            Retired
# 2    6611        3    31-35  Partner   Professional       Professional
# 3    1950     Zero    55-60  Partner   Professional       Professional
# 4   10857        2    51-55  Partner  Manual Worker      Manual Worker
#
#       home_status      family_income self_employed self_employed_partner  ...  \
# 0  Rent Privately           >=35,000           Yes                   Yes  ...
# 1        Own Home  <12,500, >=10,000            No                    No  ...
# 2        Own Home           >=35,000            No                    No  ...
# 3        Own Home           >=35,000            No                    No  ...
# 4        Own Home  <27,500, >=25,000           Yes                   Yes  ...
#
# ...

# %%
test.head()
# Out:
#    REF_NO children age_band   status         occupation occupation_partner  \
# 0       9        1    36-40  Partner       Professional       Professional
# 1      13     Zero    61-65  Partner            Retired            Retired
# 2      18     Zero    26-30  Partner            Unknown       Professional
# 3      21        1    41-45  Partner  Secretarial/Admin      Manual Worker
# 4      26     Zero    26-30  Partner       Professional       Professional
#
#   home_status      family_income self_employed self_employed_partner  ...  \
# 0    Own Home           >=35,000            No                    No  ...
# 1    Own Home  <12,500, >=10,000            No                    No  ...
# 2    Own Home           >=35,000           Yes                    No  ...
# 3    Own Home  <12,500, >=10,000            No                    No  ...
# 4    Own Home           >=35,000            No                    No  ...
#
#    Investment.in.Mutual.Fund Investment.Tax.Saving.Bond Home.Loan  \
# ...

# %%
train.columns
# Out:
# Index(['REF_NO', 'children', 'age_band', 'status', 'occupation',
#        'occupation_partner', 'home_status', 'family_income', 'self_employed',
#        'self_employed_partner', 'year_last_moved', 'TVarea', 'post_code',
#        'post_area', 'Average.Credit.Card.Transaction', 'Balance.Transfer',
#        'Term.Deposit', 'Life.Insurance', 'Medical.Insurance',
#        'Average.A.C.Balance', 'Personal.Loan', 'Investment.in.Mutual.Fund',
#        'Investment.Tax.Saving.Bond', 'Home.Loan', 'Online.Purchase.Amount',
#        'Revenue.Grid', 'gender', 'region', 'Investment.in.Commudity',
#        'Investment.in.Equity', 'Investment.in.Derivative',
#        'Portfolio.Balance'],
#       dtype='object')

# %%
train['Revenue.Grid']
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 8119    2
# 8120    2
# 8121    2
# 8122    2
# 8123    2
# Name: Revenue.Grid, Length: 8124, dtype: int64

# %%
test['Revenue.Grid']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Revenue.Grid'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-7d65ed82d0bf> in <module>
# ...

# %% [markdown]
# we can see that wehave revenue grid column in train dataset but not in test datset
# which is target value
# so we will create a column in test dataste

# %%
test['Revenue.Grid'] = np.nan

# %%
train['data'] = 'train1'

# %%
test['data'] = 'test1'

# %%
test = test[train.columns]

# %% [markdown]
# after that we will get the column names from train dataset and put those columns which are present in train into test dataset
# it will get all the columns from train and it will filter out test so that we don't have any extra column in test dataset
#
# then we will concatinate train and test datset with axis=0

# %%
all = pd.concat([train,test],axis=0) # here we have all the train dataset on the top followed by test datset

# %%
train.shape
# Out:
# (8124, 33)

# %%
test.shape
# Out:
# (2031, 33)

# %%
train.head()
# Out:
#    REF_NO children age_band   status     occupation occupation_partner  \
# 0    2148        1    45-50  Partner   Professional       Professional
# 1    8099        1    61-65  Partner        Retired            Retired
# 2    6611        3    31-35  Partner   Professional       Professional
# 3    1950     Zero    55-60  Partner   Professional       Professional
# 4   10857        2    51-55  Partner  Manual Worker      Manual Worker
#
#       home_status      family_income self_employed self_employed_partner  ...  \
# 0  Rent Privately           >=35,000           Yes                   Yes  ...
# 1        Own Home  <12,500, >=10,000            No                    No  ...
# 2        Own Home           >=35,000            No                    No  ...
# 3        Own Home           >=35,000            No                    No  ...
# 4        Own Home  <27,500, >=25,000           Yes                   Yes  ...
#
# ...

# %%
test.head()
# Out:
#    REF_NO children age_band   status         occupation occupation_partner  \
# 0       9        1    36-40  Partner       Professional       Professional
# 1      13     Zero    61-65  Partner            Retired            Retired
# 2      18     Zero    26-30  Partner            Unknown       Professional
# 3      21        1    41-45  Partner  Secretarial/Admin      Manual Worker
# 4      26     Zero    26-30  Partner       Professional       Professional
#
#   home_status      family_income self_employed self_employed_partner  ...  \
# 0    Own Home           >=35,000            No                    No  ...
# 1    Own Home  <12,500, >=10,000            No                    No  ...
# 2    Own Home           >=35,000           Yes                    No  ...
# 3    Own Home  <12,500, >=10,000            No                    No  ...
# 4    Own Home           >=35,000            No                    No  ...
#
# ...

# %%
all.head()
# Out:
#    REF_NO children age_band   status     occupation occupation_partner  \
# 0    2148        1    45-50  Partner   Professional       Professional
# 1    8099        1    61-65  Partner        Retired            Retired
# 2    6611        3    31-35  Partner   Professional       Professional
# 3    1950     Zero    55-60  Partner   Professional       Professional
# 4   10857        2    51-55  Partner  Manual Worker      Manual Worker
#
#       home_status      family_income self_employed self_employed_partner  ...  \
# 0  Rent Privately           >=35,000           Yes                   Yes  ...
# 1        Own Home  <12,500, >=10,000            No                    No  ...
# 2        Own Home           >=35,000            No                    No  ...
# 3        Own Home           >=35,000            No                    No  ...
# 4        Own Home  <27,500, >=25,000           Yes                   Yes  ...
#
# ...

# %%
train.shape
# Out:
# (8124, 33)

# %%
all.tail()
# Out:
#       REF_NO children age_band   status        occupation occupation_partner  \
# 2026   11496        2    41-45  Partner      Professional       Professional
# 2027   11503        1    45-50  Partner  Business Manager       Professional
# 2028   11509     Zero    61-65  Partner           Retired            Retired
# 2029   11511     Zero    55-60  Partner           Unknown          Housewife
# 2030   11514        2    41-45  Partner         Housewife       Professional
#
#      home_status      family_income self_employed self_employed_partner  ...  \
# 2026    Own Home  <30,000, >=27,500            No                    No  ...
# 2027    Own Home  <30,000, >=27,500            No                    No  ...
# 2028    Own Home  < 8,000, >= 4,000            No                    No  ...
# 2029    Own Home  <27,500, >=25,000           Yes                    No  ...
# 2030    Own Home           >=35,000            No                    No  ...
#
# ...

# %% [markdown]
# train dataset are at top
#
# test dataset are at bottom

# %%
# let's check revenue grid value

# %%
all['Revenue.Grid'].value_counts()
# Out:
# 2.0    7261
# 1.0     863
# Name: Revenue.Grid, dtype: int64

# %%
7261/863
# Out:
# 8.413673232908458

# %%
# we can see that it is imbalance class

# %%
# now we will balance this class

# %%
all.columns
# Out:
# Index(['REF_NO', 'children', 'age_band', 'status', 'occupation',
#        'occupation_partner', 'home_status', 'family_income', 'self_employed',
#        'self_employed_partner', 'year_last_moved', 'TVarea', 'post_code',
#        'post_area', 'Average.Credit.Card.Transaction', 'Balance.Transfer',
#        'Term.Deposit', 'Life.Insurance', 'Medical.Insurance',
#        'Average.A.C.Balance', 'Personal.Loan', 'Investment.in.Mutual.Fund',
#        'Investment.Tax.Saving.Bond', 'Home.Loan', 'Online.Purchase.Amount',
#        'Revenue.Grid', 'gender', 'region', 'Investment.in.Commudity',
#        'Investment.in.Equity', 'Investment.in.Derivative', 'Portfolio.Balance',
#        'data'],
#       dtype='object')

# %%
all.dtypes
# Out:
# REF_NO                               int64
# children                            object
# age_band                            object
# status                              object
# occupation                          object
# occupation_partner                  object
# home_status                         object
# family_income                       object
# self_employed                       object
# self_employed_partner               object
# year_last_moved                      int64
# TVarea                              object
# post_code                           object
# post_area                           object
# Average.Credit.Card.Transaction    float64
# Balance.Transfer                   float64
# Term.Deposit                       float64
# Life.Insurance                     float64
# Medical.Insurance                  float64
# Average.A.C.Balance                float64
# Personal.Loan                      float64
# Investment.in.Mutual.Fund          float64
# ...

# %%
all.nunique()
# Out:
# REF_NO                             10155
# children                               5
# age_band                              13
# status                                 5
# occupation                             9
# occupation_partner                     9
# home_status                            5
# family_income                         13
# self_employed                          2
# self_employed_partner                  2
# year_last_moved                       95
# TVarea                                14
# post_code                          10040
# post_area                           2039
# Average.Credit.Card.Transaction     1411
# Balance.Transfer                    2183
# Term.Deposit                        1419
# Life.Insurance                      3111
# Medical.Insurance                   1589
# Average.A.C.Balance                 2223
# Personal.Loan                       1760
# Investment.in.Mutual.Fund           2470
# Investment.Tax.Saving.Bond           832
# ...

# %%
list(zip(all.columns,all.dtypes,all.nunique()))
# Out:
# [('REF_NO', dtype('int64'), 10155),
#  ('children', dtype('O'), 5),
#  ('age_band', dtype('O'), 13),
#  ('status', dtype('O'), 5),
#  ('occupation', dtype('O'), 9),
#  ('occupation_partner', dtype('O'), 9),
#  ('home_status', dtype('O'), 5),
#  ('family_income', dtype('O'), 13),
#  ('self_employed', dtype('O'), 2),
#  ('self_employed_partner', dtype('O'), 2),
#  ('year_last_moved', dtype('int64'), 95),
#  ('TVarea', dtype('O'), 14),
#  ('post_code', dtype('O'), 10040),
#  ('post_area', dtype('O'), 2039),
#  ('Average.Credit.Card.Transaction', dtype('float64'), 1411),
#  ('Balance.Transfer', dtype('float64'), 2183),
#  ('Term.Deposit', dtype('float64'), 1419),
#  ('Life.Insurance', dtype('float64'), 3111),
#  ('Medical.Insurance', dtype('float64'), 1589),
#  ('Average.A.C.Balance', dtype('float64'), 2223),
#  ('Personal.Loan', dtype('float64'), 1760),
#  ('Investment.in.Mutual.Fund', dtype('float64'), 2470),
#  ('Investment.Tax.Saving.Bond', dtype('float64'), 832),
# ...

# %% [markdown]
# - ref no, application no, roll no, ssn no  all of these number will not impact the how the model is working
#
# if we change the ref no or loan application id will it impact on loan approval answer is no ref no has no realation whith loan approval
# so we can remove this ref no
#
# - next we have children column children column has dtype 'o' means object
#
# we have to convert it into numeric form when we look to children column it has all the data numeric except  'zero ' so we will convert string zero to numeric
#
# - next is age band
#
# age band column has value with difference of 5
# so we can take mean age from age band and can create new column which has mean of range like 41-45, 45-50 etc
#
# - next we have status column it has datatype object and there are 5 type of object present
#
# so we will analyze we will convert it into numeric column by using one hot encoding
#
# - next is occupation occupation is also object and it has 9 different value
#
# we will have to decide if we need to keep all the 9 values or we have to keep only top 5 or top 4
#
# - then same thing with occuption_partner , home_status
#
# - Next is family income it should be in numeric nature but it is in object form becuse it is in range
#
# range has not fix gap so we can't take mean here we have to divide that column into maxincome and minincome
# or we can create level like 4k-6k L1, 6k-8k L2 etc
#
# - then we have self_employee it is binary in nature so we can convert it into 0 or 1 form
#
# - same thing we can apply to self_employee partner
#
# - SO we only need to take care of Obhect datatype

# %%
all.head()
# Out:
#    REF_NO children age_band   status     occupation occupation_partner  \
# 0    2148        1    45-50  Partner   Professional       Professional
# 1    8099        1    61-65  Partner        Retired            Retired
# 2    6611        3    31-35  Partner   Professional       Professional
# 3    1950     Zero    55-60  Partner   Professional       Professional
# 4   10857        2    51-55  Partner  Manual Worker      Manual Worker
#
#       home_status      family_income self_employed self_employed_partner  ...  \
# 0  Rent Privately           >=35,000           Yes                   Yes  ...
# 1        Own Home  <12,500, >=10,000            No                    No  ...
# 2        Own Home           >=35,000            No                    No  ...
# 3        Own Home           >=35,000            No                    No  ...
# 4        Own Home  <27,500, >=25,000           Yes                   Yes  ...
#
# ...

# %%
all['region'].value_counts()
# Out:
# South East          2100
# North West          1896
# Unknown             1080
# South West           971
# West Midlands        820
# Scotland             787
# East Midlands        771
# North                571
# Wales                556
# East Anglia          423
# Northern Ireland     159
# Isle of Man           16
# Channel Islands        5
# Name: region, dtype: int64

# %%
# REF_NO, post-code, post_area :drop
# children : zero : 0 4+ : 4 and then convert to numeric
# age_band :dummies
# status,occupation,occupation_partner, home_status, family_income:dummies variable 
# self_employed, " dummies"
# TVArea , region, gender : dummies
# Revenue grid : 1,2 :1,0

# %% [markdown]
# post code and post area has object type datatype but has lots of cardinality
# it has very high cardinality w.r.t object datatype
# it has lot of irrelevant data we can not convert 10000 value into 10000 dummy value
#
# so simply we can get rid of these column
#
# and same thing will apply to post code
#
# --------------------------
# ------------------------------
# ------------------------------------------
#
# for children column we will convert
# Zero to : 0
# 4+ : 4
#
# --------------------------
# ------------------------------
# ------------------------------------------
#
# age_band :dummies
# status,occupation,occupation_partner, home_status, family_income:dummies variable
# self_employed, " dummies"
# TVArea , region, gender : dummies
#
# we will convert all these columns into dummies
#
# --------------------------
# ------------------------------
# ------------------------------------------
#
# and then we will convert Revenue grid into 1 and 0

# %%
all.drop(['REF_NO','post_code','post_area'], axis=1, inplace=True)

# %%
all['children'] = np.where(all['children']=='Zero',0,all['children'])
all['children'] = np.where(all['children'][:1]=='4',4,all['children'])
all['children'] = np.where(all['children'][:1]=='4+',4,all['children'])
all['children'] = pd.to_numeric(all['children'], errors='coerce')

# %%
all.head(10)
# Out:
#    children age_band   status         occupation occupation_partner  \
# 0       1.0    45-50  Partner       Professional       Professional
# 1       1.0    61-65  Partner            Retired            Retired
# 2       3.0    31-35  Partner       Professional       Professional
# 3       0.0    55-60  Partner       Professional       Professional
# 4       2.0    51-55  Partner      Manual Worker      Manual Worker
# 5       2.0    31-35  Partner       Professional       Professional
# 6       3.0    36-40  Partner  Secretarial/Admin            Unknown
# 7       1.0    41-45  Partner              Other       Professional
# 8       2.0    26-30  Partner  Secretarial/Admin      Manual Worker
# 9       3.0    31-35  Partner   Business Manager      Manual Worker
#
#       home_status      family_income self_employed self_employed_partner  \
# 0  Rent Privately           >=35,000           Yes                   Yes
# ...

# %%
all['children'].value_counts()
# Out:
# 0.0    6208
# 1.0    1848
# 2.0    1607
# 3.0     473
# Name: children, dtype: int64

# %%
all['children'].nunique()
# Out:
# 4

# %%
all['Revenue.Grid']
# Out:
# 0       2.0
# 1       2.0
# 2       2.0
# 3       2.0
# 4       2.0
#        ...
# 2026    NaN
# 2027    NaN
# 2028    NaN
# 2029    NaN
# 2030    NaN
# Name: Revenue.Grid, Length: 10155, dtype: float64

# %% [markdown]
# so here we are checking np.where so whenever the children value is zero we are putting 0 otherwise we are putting original value
#
# here we are puttinh error ='coerce' so if there is misssing value so it will put null values

# %%
all['Revenue.Grid']= (all['Revenue.Grid']==1).astype(int)

# %%
all['Revenue.Grid']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2026    0
# 2027    0
# 2028    0
# 2029    0
# 2030    0
# Name: Revenue.Grid, Length: 10155, dtype: int32

# %%
all['Revenue.Grid']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2026    0
# 2027    0
# 2028    0
# 2029    0
# 2030    0
# Name: Revenue.Grid, Length: 10155, dtype: int32

# %% [markdown]
# So here for value 1 it will convert to 1 and for value 2 it will convert to 0

# %%
catagorical = all.select_dtypes(['object']).columns

# %%
catagorical
# Out:
# Index(['age_band', 'status', 'occupation', 'occupation_partner', 'home_status',
#        'family_income', 'self_employed', 'self_employed_partner', 'TVarea',
#        'gender', 'region', 'data'],
#       dtype='object')

# %% [markdown]
# here we are seleting catagorical columns from data

# %%
for col in catagorical[:-1]: # it means except for -1 because we don't want to transform data columns
    dummy = pd.get_dummies(all[col],drop_first=True,prefix=col)
    all = pd.concat([all,dummy], axis=1)
    del all[col]
    print(col)
    
del dummy
# Out:
# age_band
# status
# occupation
# occupation_partner
# home_status
# family_income
# self_employed
# self_employed_partner
# TVarea
# gender
# region

# %%
all.shape
# Out:
# (10155, 96)

# %%
all.isnull().sum()
# Out:
# children                           19
# year_last_moved                     0
# Average.Credit.Card.Transaction     0
# Balance.Transfer                    0
# Term.Deposit                        0
#                                    ..
# region_South East                   0
# region_South West                   0
# region_Unknown                      0
# region_Wales                        0
# region_West Midlands                0
# Length: 96, dtype: int64

# %%
all.loc[all['children'].isnull(),'children']=all.loc[all['data']=='train','children'].mean()

# %% [markdown]
# whereever children value is null select the children column  and in that column we are putting the train data and putting mean of children column
#
# so it is taking not mean of the entire data but it is taking only mean of children data

# %%
train = all[all['data']=='train1']
del train['data']
test = all[all['data']=='test1']
test.drop(['Revenue.Grid','data'],axis=1,inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
all.head()
# Out:
#    children  year_last_moved  Average.Credit.Card.Transaction  \
# 0       1.0             1999                             0.00
# 1       1.0             1959                             0.00
# 2       3.0             1992                           119.98
# 3       0.0             1990                             0.00
# 4       2.0             1994                             0.00
#
#    Balance.Transfer  Term.Deposit  Life.Insurance  Medical.Insurance  \
# 0              0.00        196.95          132.42               0.00
# 1             77.89          0.00          134.39               0.00
# 2              0.00         96.94            0.00             159.97
# 3             39.99          0.00          133.93               0.00
# 4            161.47         14.99           58.97               7.49
#
#    Average.A.C.Balance  Personal.Loan  Investment.in.Mutual.Fund  ...  \
# 0                 0.00          21.47                      24.18  ...
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score 
from sklearn.model_selection import GridSearchCV

# %%
#Here we are seelcting parametr for matrix

# %% [markdown]
# params = {'class-weight':['balanced',None,{1:1,0:8.41}],
#          'penalty':['l1','l2'],
#          'C':np.linspace(0.01,1000,10)}# l1 for ridge l2 for lasso

# %%
params={'class_weight':['balanced',None,{1:1,0:8.41}],
        'penalty':['l1','l2'],
        'C':np.linspace(0.01,1000,10)}

# %%
model = LogisticRegression(fit_intercept=True)

# %%
grid_search = GridSearchCV(model,param_grid=params,cv=5,scoring='roc_auc')

# %%
x_train = train.drop('Revenue.Grid',axis=1)
y_train = train['Revenue.Grid']

# %%
train.dtypes
# Out:
# children                           float64
# year_last_moved                      int64
# Average.Credit.Card.Transaction    float64
# Balance.Transfer                   float64
# Term.Deposit                       float64
#                                     ...
# region_South East                    uint8
# region_South West                    uint8
# region_Unknown                       uint8
# region_Wales                         uint8
# region_West Midlands                 uint8
# Length: 95, dtype: object

# %%
train.nunique()
# Out:
# children                              4
# year_last_moved                      92
# Average.Credit.Card.Transaction    1233
# Balance.Transfer                   1901
# Term.Deposit                       1251
#                                    ...
# region_South East                     2
# region_South West                     2
# region_Unknown                        2
# region_Wales                          2
# region_West Midlands                  2
# Length: 95, dtype: int64

# %%
train.isnull().sum()
# Out:
# children                           12
# year_last_moved                     0
# Average.Credit.Card.Transaction     0
# Balance.Transfer                    0
# Term.Deposit                        0
#                                    ..
# region_South East                   0
# region_South West                   0
# region_Unknown                      0
# region_Wales                        0
# region_West Midlands                0
# Length: 95, dtype: int64

# %%
test.isnull().sum()
# Out:
# children                           7
# year_last_moved                    0
# Average.Credit.Card.Transaction    0
# Balance.Transfer                   0
# Term.Deposit                       0
#                                   ..
# region_South East                  0
# region_South West                  0
# region_Unknown                     0
# region_Wales                       0
# region_West Midlands               0
# Length: 94, dtype: int64

# %%
mean1 = train['children'].mean()

# %%
mean2 = test['children'].mean()

# %%
train['children'].fillna(value=mean1, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
test['children'].fillna(value=mean2, inplace=True)

# %%
np.isnan(x_train.any())
# Out:
# children                           False
# year_last_moved                    False
# Average.Credit.Card.Transaction    False
# Balance.Transfer                   False
# Term.Deposit                       False
#                                    ...
# region_South East                  False
# region_South West                  False
# region_Unknown                     False
# region_Wales                       False
# region_West Midlands               False
# Length: 94, dtype: bool

# %%
np.isfinite(y_train.all())
# Out:
# True

# %%
np.any(np.isnan(x_train))
# Out:
# True

# %%
np.all(np.isfinite(y_train))
# Out:
# True

# %%
x_train = np.nan_to_num(x_train)

# %%
np.any(np.isnan(x_train))
# Out:
# False

# %%
x_train.replace([np.inf, -np.inf], np.nan, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-62d709997bbb> in <module>
# ----> 1 x_train.replace([np.inf, -np.inf], np.nan, inplace=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'replace'

# %%
'''import pandas as pd

def clean_dataset(df):
    assert isinstance(x_train, pd.DataFrame), "df needs to be a pd.DataFrame"
    x_train.dropna(inplace=True)
    indices_to_keep = ~x_train.isin([np.nan, np.inf, -np.inf]).any(1)
    return x_train[indices_to_keep].astype(np.float64)'''

# %%
'''import pandas as pd

def clean_dataset(df):
    assert isinstance(x_test, pd.DataFrame), "df needs to be a pd.DataFrame"
    x_test.dropna(inplace=True)
    indices_to_keep = ~x_train.isin([np.nan, np.inf, -np.inf]).any(1)
    return x_train[indices_to_keep].astype(np.float64)'''

# %%
import pandas as pd

def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
x_train = pd.DataFrame(x_train)

# %%
x_train = clean_dataset(x_train)

# %%
y_train = pd.DataFrame(y_train)

# %%
y_train = clean_dataset(y_train)

# %%
grid_search.fit(x_train,y_train)
# Out:
# C:\Users\Admin\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Admin\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Admin\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
grid_search.best_estimator_

# %%
grid_search.best_params_
