# %% [markdown]
# # Random Forest

# %% [markdown]
# In this we will learn about first ensemble method which is  nothing but bagging in the form of Random forest

# %% [markdown]
# ![86.JPG](attachment:86.JPG)

# %% [markdown]
# Let's first discuss about decision trees

# %% [markdown]
# ![87.JPG](attachment:87.JPG)

# %% [markdown]
# - Now here we will be creating a random forest
#
# - Random Forest is an implementation of bagging
#
# - And bagging helps us to reduce the variance
#
# - So how we do this we basically combine different dtumps and we take average of them so that we get low variance model

# %% [markdown]
# ![88.JPG](attachment:88.JPG)

# %% [markdown]
# - So in case of decision trees we have high variance so what we do is we basically use stumps so that we could have low variance in this particular situations

# %% [markdown]
# Random forest is a group of small decision trees that is a group of stumps which we take and using this group of stumps  we create huge forest
#
# Forest is something which contains a lot of trees
# so same thing is here we are creating forest decision stumps Now when we are creating the forest of decision stumps we need to add randomness
#
# So when we are saying that random forest it means we are creating a forest and we have to add some randomeness to it
#
# Now how are we introducing this randomness , this randomness is introduce by creating subset of samples which is taken for the training of each and evry tree
#
# So when we will be creating decision tree we consider all the feature which are present
#
# In case of random forest when we will be creating decision stumps we will be taking the small samples of the data instead of considering all samples of the data
#
# So we take only small samples of data so that we can get only subset of the data points i.e Only a subset of patterns from the data
#
# The next thing what we do is we also take a subset of variable by training each tree
#
# now what happen when we are taking subset of variable because we are taking subset of variable so instead of having all the features present for creating a tree we are now havingdifferent subsets of features for creating that decision  tree
#
# Now imagine if we would have used the complete set of features for creating the decision stumps then what would have happen is  that it will evaluate all the roots and because it is evaluating all teh rules on the basis of of same ginni index or sum of square errors that is why it will be predicting the rules which has highest gini gain  so that is the reason why it will select same split at the first and then followed by next split
#
# SO the decision tree which will be formulated will be just the same because there is no new feature or subset of feature hence it will create same decision tree because there is no variation
#
# SO that is why we need to provide variations in the form of randomness

# %% [markdown]
# Which is the reason why we are looking at sample subset , so from the entire data we will look at the small samples of the data at every time  and for creating the rules we will not be creating the rules from all variables , we will creating only rules from the small subset of variables
#
# Now again , for each and every split which we will be creating the rules are not considered from all in variables
#
# Let us say initially we had k varaible from which we use to create our decision
# these k variables are all variables which we had
#
# So now for craeting stump 1 ,2,3,4 we will take small subset of this k varaibles
#
# So now subset have n number of variables , so each model will be created from n number of variables and while craeting the subset , while creating small stump out of this n varaibles
# each split which we will be making now the rules will be not picked out from n variables but agian a subset of this n  variables

# %% [markdown]
# ![100.JPG](attachment:100.JPG)
