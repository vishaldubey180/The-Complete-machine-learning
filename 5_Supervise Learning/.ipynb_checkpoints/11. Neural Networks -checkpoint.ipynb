# %% [markdown]
# # Neural Networks

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# - Neural network is technique for building a computer program that learns from the data
#
# this is exactly what machine learning is also doing so what is difference here
#
# - Neural network based on very loosely on how we think the human brains work
#
# so just how the hman brain work in same ay neural network also work
#
# in our brains , there are sevearl neurons which are connected with each other and they pass  message from one to other which are decrypted by tyese neurons and then we are able to think or fell something
#
#
# In neural networks a collection of software nerons are created and connected together which which allow them to send message to each other
# Now the network is asked to solve this particular problem , So we will provide a particular problem to the network and the network will try to solve the problem , and it will try to solve it again,again,again till the time it actually complete the learning process , till the time it actually able to perform that particular calculation it will keep on doing it again n again
# so at every iteration when it is learning or sending the message again n again , it actually keeps connecting the dots and it actually keeps learning from the data and improve the predictions which it is making
#
# so that is how nerual networks work

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %% [markdown]
# So here we have a lot of cicles connecetd
#
# Input nodes - The ones in the green
# blue nodes -  other nodes to which green nodes are connected to
# output or decision points - RED
#
# So here all we want to do is we want to send our input values or x values or features or attributes from input green nodes
#
# and these green neruons will pass on the information to blue neurons
#
# blue neurons will actually try to decrypt the pattern between these green nodes and send out there learning to red node which will finally decide what the output will be
# let's say if we are looking for continuous value then what value should be predicted ,
# and in case we are looking for class then it should be yes or no
#
# so this is Neural network

# %% [markdown]
# ![3.JPG](attachment:3.JPG)

# %% [markdown]
# Logistic regression is very smallest example of neural network
#
# in image we can see that there are several input values
# and these input values will be giving certain probability to us
# this is logistic regression , in logistic regression we have several input values and we apply a sigmoid function on top of it that we convert  this particular input into our equations
# the equation will be b1x1+b2x2+b3x3 and so on
#
# then we apply sigmoid function on it or logit function
#
# logit function is one upon one plus E to the power - the equation which we just formulated
#
# so this is how small blue cicle or sigmoid function will result the probability

# %% [markdown]
# ![4.JPG](attachment:4.JPG)

# %% [markdown]
# Neural networks is not something to which we go towords  at very begning or we are starting to solve a particular problem
#
# Whenever we are starting to solve particular problem in that acse , we will first of all implement linear model then we will implement the decision tree and after that we will decide if we want  to go towords the bagging or boosting
#
# in case we have less amount of data then algorithm like SVM , knn, naive bayes , xgboost, random forest all these algorithm will be more favourable
#
# But in case we are trying to have more precision or a better model then in that case we will going towards nural networks but while going towards neural netowrks the main challange we will face is lack of data
#
# Because a nerual network required a lot of data to train it , this is the reason why we can not implement nerual networks for all type of problems , because we neeed a lot of data to get good output from the neural network
#
# hence it is used majorly for the problems like audio data  or video data where we can have exhaustive amount of example presents then we can apply neural networks on them
#
# small circles or small blocks are called nodes
#
#
# each neruon hold some information and each connecting line will hold weight
#
# weights are  nothing but the beeta value in logistic regression
#
# so in case of logistic regression we had betta values with which we multiply these input values

# %% [markdown]
# ![5.JPG](attachment:5.JPG)

# %% [raw]
# In  digram
#
# input datapoints - x1,x2,x3...xn
#
# weight value - w1,w2,w3,..... wn
#
# then we have net function(sum of all input multply by weight )
#
#
# then we have activation function which is nothing but logistic function or logit function or sigmoid function or it may be any activation function
#
#
# if we want to get probability as an output or we want to solve a classification problem in that case we can use logit function
#
# but in case we want to find out continuous value then we should not use this function because this will convert the range of the data
#
# we have read that the equation of linear line , linear equation is converted to lgistic equation , into a curved equation because of this activation function
#
# so we have converetd linear equation into non-linear equation using that is something which is having a range from zero to one using the sigmoid function
#
# so if we want to predict the continuous value i.e if we want to solve the regression problem then we don't need to have the activation function(sigmoid) at the end of  neural network
#
# because sigmoid function will change the regression problem into classification problem

# %% [markdown]
# ![6.JPG](attachment:6.JPG)

# %% [markdown]
# how to deal with complex problems

# %% [markdown]
# ![7.JPG](attachment:7.JPG)

# %% [markdown]
# For complex problems we add several layers to neural networks
#
# So to solve complex problems we add multiple hidden layer which will give us proper output

# %% [markdown]
# ![8.JPG](attachment:8.JPG)

# %% [markdown]
# most activation function is used sigmoid function then second most used activation function is RELU

# %% [markdown]
# Let'say we are creating linear regression or lostic regression and instead of using sigmoid function if we apply a linear function then the output of this will be linear equation
#
# so we should always use non-linear transforming function so that it can capture diffreent complex pattern

# %% [markdown]
# ![6.JPG](attachment:6.JPG)

# %% [markdown]
# Let's look at below example

# %% [markdown]
# ![7.JPG](attachment:7.JPG)

# %% [markdown]
# here we have two hidden layers
#
# each input is connecetd to both the point of hidden layer 1
# and both point of hidden layer1 is connected to all the five dots of hidden layer 2
#
# and then all five circles of hidden layer 2 will be conceted to all output which is not shown in digram
#
#
# So initially input will have certain values those values will be mutiplied by their weights and added together and pushed into sigmoid function
# similarly same thing will be pushed to other sigmoid function
#
# same will be applied for hidden layer2

# %% [markdown]
# ![9.JPG](attachment:9.JPG)

# %% [markdown]
# Chain rule is used for updating the value of the weights
# because in entire process we know the input value , we know the function which we are applying but the only thing which we don't know is the value of weights present on the line
#
# so we need to find the value of weights
#
# So we can find the value of weights by chain rule
#
# here we have two input a and b
# we have two sigmoid function c=a*b and d=b+1
# and final output is given by e=c*d
#
# if we know only the value of e=c*d
#
# then how can we find out the value of a and b
#
# then we have to go in backword direction
#
# a,b -->e forword
# e --> a,b backword
#
# so in backword propagation we take derivative of e w.r.t e which is 1
#
# derivative of e w.r.t d is de/dc
#
# derivative of e w.r.t c is de/dd
#
# again we do the same thing for a and b

# %% [markdown]
# ![10.JPG](attachment:10.JPG)

# %% [markdown]
# So what happen fisrt we have input value , activation function but w edon't have output
#
# we complete one  forword process andand based on the some random weights value we  get the output but this output is not same as actual output
#
# so we will have to go in backword direction to updates the weights because only updating the weights can improve the output
#
# we will do this backpropagation until we get the output values which are very close to actual values

# %% [markdown]
# ![11.JPG](attachment:11.JPG)

# %% [markdown]
# So here we have input value
#
# and input value is multiplied by some weight1
#
# then in hidden layer 1 we have some activation function
#
# weight *input goes into actvation function of hidden layer 1 and the output of hidden layer will applied by w2 and then it goes to activation function of hidden layer 2 and so on
#
# and then we get output

# %% [markdown]
# ![12.JPG](attachment:12.JPG)

# %% [markdown]
# So when we subtract the predicted value with the actual value we will get some error
#
# so we will do backpropagation so that to update the weight and reduce the error

# %% [markdown]
# ## Let's calculate the error values ,

# %% [markdown]
# ![13.JPG](attachment:13.JPG)

# %% [markdown]
# In aove digram let's say we have
# input xi = x1,x2,x3,...xn
# weight wi = w1,w1,...wn
# sum  = si
# activation function  = theta
#
#
# so if we want to find out the change in error w.r.t change in weight
#
# we can see in above digram

# %% [markdown]
# ![14.JPG](attachment:14.JPG)

# %% [markdown]
# ![15.JPG](attachment:15.JPG)

# %% [markdown]
# ![16.JPG](attachment:16.JPG)
