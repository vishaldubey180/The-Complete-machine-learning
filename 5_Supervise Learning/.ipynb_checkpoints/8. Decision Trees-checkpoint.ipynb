# %% [markdown]
# # Decision Trees

# %% [markdown]
# ![50.JPG](attachment:50.JPG)

# %% [markdown]
# - We have seen that linear model try to create an equation of a straight line and try to fit data to it
# - In case of decision tree we try to create a sequence of decision nodes or a tree like structure where we will make decision at different points and at the end of all the decision we will get the target value

# %% [markdown]
# ![51.JPG](attachment:51.JPG)

# %% [markdown]
# - So in this particular tree we have different values here we have values like dependent variable and independent varaible in the tree
# - in this kind of tree the dependent variable is the data which is present inside the tree i.e the data which is pointing to either a child should play or not play
# - and the independent variables or the featurees or attribute become the decision points
# - so each decision point will be created from the feature column
# - so in this particyular data the featurecolumns are outlook of the day humidity of the day and a if a daya is windy or not
# - So this kind of structure would be generated and based on this structure at the end of the tree we will be getting if a child should play or not

# %% [markdown]
# # Different types of term in decision tree

# %% [markdown]
# ![52.JPG](attachment:52.JPG)

# %% [markdown]
# - so in ex digram we have this entire tree and the place where the tree begins is called the root node
# - this root node contain all the data i.e all 14 rows of data which we have
# - and further each decision which we take divide these 14 rows of the data into 14 rows of data into smaller chunk
# - the node which is created from parent node is called as child node

# %% [markdown]
# # Process

# %% [markdown]
# ![53.JPG](attachment:53.JPG)

# %% [markdown]
# - For creating the decision tree we need to have root node or decision node and all the rows of data in hand
# - Now after we have all the rows of data we need to define one particular rule on the basis of which we will be splitting the nodes
# - once we have selected that particular rule then we will be doing split
# - and after one particular split have been made then again we will evaluate all the rules which are present and we will compare all the rules and find out next best rules on the basis of which we will be making split
# - Now how we will generate these rules and how we will compare these rules we will learn here
# - first let's see how we make decision
# - So we will have certain rules on the basis of which we will be subdividing
# - so at the final stage when we have so based on the majority values of leaf node we will decide if child should play or not
# _____________________
# ____
# ________________
#
# - we can solve both type of problem using decision tree
#
# - In case of classifiction we can either find out by probability or the hard class
# - if we want to find out probability then we can find out the probability by obtaining the proportion of the values at the leaf node
# - we can find the hard class by selecting the majority votes

# %% [markdown]
# # Rules Creation

# %% [markdown]
# ![54.JPG](attachment:54.JPG)

# %% [markdown]
# - So for creating rules for numeric variable we will split them into random ranges

# %% [markdown]
# ![55.JPG](attachment:55.JPG)

# %% [markdown]
# # Decision Tree spliting

# %% [markdown]
# We know that decision tree are based on the different rules which we have , and these rules define what decision node has to be placed next
#
# Now let's learn Tree splitting

# %% [markdown]
# ![56.JPG](attachment:56.JPG)

# %% [markdown]
# - So each split is made would be aligned to an axis with each feature present on the an axis
# - So it means that each split made would be aligned to an axis where region is in axis itself

# %% [markdown]
# - Let's consider the data where we have values or we can consider these value being different classes
# - So these classes are present in 4 different region
# - If we want to subdivide and try to find out where what class is present then if we want to make such decision what is the way
# - So we can do this by creating rules
# - So can create first rule as x>0.5
# - When x is greater than 0.5 than that line would be selected which mean if x is greater than 5 then x would be part of class 1 or 3
# - Then we have another condition that y<0.5
# - So for the tree where we have x>0.5 and y<0.5 that would mean it belong to class 1
# - So now remeber the condition we created x >0.5 for the condition yes above scenario will be true but for the condition NO i.e x<0.5
# - So for x<0.5 we have two type condition present x>-1.1 then again we would have to split y axis so if the value of y>-0.5  then it belong to 4 otherwise 2
# - Now we can do the split based on the y-axis

# %% [markdown]
# ![57.JPG](attachment:57.JPG)

# %% [markdown]
# So how ill we actually get to know that these rule are actually useful?

# %% [markdown]
# - SO for that we will select most homogenous child node
# - The different criteria for rule selection is gini index, entropy, deviance
# - These are three formulas which is used for creating ans selecting the rules

# %% [markdown]
# gini index = 1-summation of probability swuare
#
#
# entropy  = -(summation of probability * log of probability
#
#
# deviance = -(summation of numbers * log of probabiity)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             )

# %% [markdown]
# Let's understand theoratically what it means

# %% [markdown]
# ![58.JPG](attachment:58.JPG)

# %% [markdown]
# - Let's say in first digram we have dataset, this data contain 4 classes , these 4 classes of blue, green,red and yellow
# - Out of these four classes we have equal amount of data present in all the four class
# - Now we want to decide that what class is where
# - For this we have to create split in that data so that we will be able to recognize what class it is
#
# ---------------
#
# - So let's amke first split , when we do first split horizontally our data will be divided into two parts top portion and bottom portion
#
# In the top portion we have some part of red points , few blue points and all the yellow points
#
# while in the bottom split we have some of the red points ,  all the green points and some of the blue points
#
# so here we don't have any clear majority of any point presence
#
# - Now  let's make  second  split , when we do second  split verticaly  our data will be divided into two parts left portion and right portion
#
# left hand side data contain only two types of data points which is blue and green
#
# and that too all of the blue and green points
#
# Right  hand side data also contain only two types of data points which is red  and yellow
#
# and that too all of the red  and yellow  points

# %% [markdown]
# - Now when we try to make another split then also split two contain all the data point of one class at one portion and it require less split as compare to first
# - So it is better to make split two in comparision to split one because it divides the data to be in more homogenous location

# %% [markdown]
# **INFORMATION GAIN**

# %% [markdown]
# ![59.JPG](attachment:59.JPG)

# %% [markdown]
# To know about informatiom gain let's first find out probability
#
# - here we have 12 datapoints herev we are making a split and diividing it into two subnodes
#
# - So probability of getting green in parent node is 0.50
#
# - probability of getting green in subnodes is 0.42,.06,0.8,0.28
#
# - In first split the data are less homogenous
#
# - while in second split the datapoints are more homogenous
#
# - so we will consider second split as best split

# %% [markdown]
# ![60.JPG](attachment:60.JPG)

# %% [markdown]
# - So now when we compare the gain with 0.014 with 0.128
# - we can see that gain for second split is more in comparison to first split
# - so we will split second split
# - we keep on splitting until we reach the stopping point of splitting

# %% [markdown]
# ![61.JPG](attachment:61.JPG)

# %% [markdown]
# Here we have these data where e have this line of seperation
#
# SO let's try to crete rule's for this or decision tree for this
#
# so the first split which we create is x1<3.5
#
# again we do splitting as shown in digram
#
# Once we have got homogenous spaces that has all the point then there is no meaning of creating for the split because the ginni index for that particular area will be stay 100% and again if we make split it will be still 100%
#
# So there is no information gain present  , So unless and until we have prominant information gain we will not make further split
#
# Because if we keep on making up for the split , there will keep on growing and it will not support anytging , it will just keep increasing the size of the tree without giving much information
#
# And if we keep splitting out the tree it can cause overfitting

# %% [markdown]
# ### Regression Trees

# %% [markdown]
# ![62.JPG](attachment:62.JPG)

# %% [markdown]
# Regression trees are what we use in the case of regression

# %% [markdown]
# ![63.JPG](attachment:63.JPG)

# %% [markdown]
# For selection of rules in collection scenarios , we were using gini index or entropy
#
# But in case of regression we use the sum of squared error
#
# So we will find out the sum of squared error of diferent type of splits
#
# and then find out the minimum split the value which has the minimum sumof squared error
#
# - So we have original value or parent node value  it contain the values 5,6,4,6,11 etc
# - predicted value will be the avg of mean of original values
# - if we subtract the predicted value from actual value we will get certain erros
# - then we will do sqr of all errors and add them
# and we will get sum of sqrd error
#
# - Now we will make to certain splits and by making the splits we will have to find out which one has minimum sum of sqrd error

# %% [markdown]
# ![64.JPG](attachment:64.JPG)

# %% [markdown]
# So here we have done first split which divide the data into two parts left and right
#
# we can see the sum of sqrd error is 95.75 and the original one is  95.8 so there is not much difference here we have no information gain
#
# let's do another split

# %% [markdown]
# ![65.JPG](attachment:65.JPG)

# %% [markdown]
# - here we got sum of sqrd error as 4.75
#
# - So as we can see that second split is better as it reduces the sum of sqyared error by 91

# %% [markdown]
# ![66.JPG](attachment:66.JPG)

# %% [markdown]
# - In dig blue line shows that how we have created different decision nodes and created split so that we have decision tree
# - Now this decision tree is able to predict the training data very greatly and all the values are predicted very finely
#
# - But when we are actually trying to predict certain values sucha as the value sum blue point it will give lot of error
#
# - we can solve this proble by using linear regression
#
# - **So this is the reaso why we should always start with very basic model, always implement the linear regression or logistic regression and then slowly and gradually get to the next models and see what is the level of improvement we are getting**
# - **If we are not getting much improvement using the higjer level of algorithm then we should always use the simpler model i.e linear regression or the mdoel which gives betetr accuracy**

# %% [markdown]
# ![67.JPG](attachment:67.JPG)

# %% [markdown]
# - we should decide the maximum depth value and based on the maximum depth value we can stop at that depth let's say 5,7,12
# - we should not allows the tree to grow alot
# - we can also set the maximum number of leaf
# - let's say we have 100 rows of the data and we are making particular split and parent value have 4 value of 1 class and 5 value of another class now if we make split then it will create and give us one node with 4 value and another node with 5 value
# - So this kind of split will giving me one node which has less than five value which is a very low number of values
# - we could have set the minimum number of leaf node observation to 20 in case if we had larger amount of data  like 1000
# - let's say we have 1000 points in the entire data then in that case we could set the 10 or 20 as the lower number
# - so we haev to decide on the basis of how much data we actually have so that we don't end up with vey minimal amount of daa , which dos not actually count for good majority
# - the split result in leaf node having less than lower limit values
#
# - So eitehr the leaf node has low limit values or the split after this particular leaf node will result in lower limit of value then we should stop splitting

# %% [markdown]
# ![68.JPG](attachment:68.JPG)

# %% [markdown]
# - citeria - define which method we are choosing
# - splitter - we can select best splitter or random splitter
# - max_depth - define max_depth of tye tree

# %% [markdown]
# ![69.JPG](attachment:69.JPG)

# %% [markdown]
# ![70.JPG](attachment:70.JPG)
