# %% [markdown]
# # Linear Regression Introduction

# %% [markdown]
# ![9.JPG](attachment:9.JPG)

# %% [markdown]
# - let's assume above is the data which we have in our hand and we have only one input variable which is the education
# - and based on the education we want to predict the income of the person
# - we can predict this by using the linear regression
# - what linear regression suggest is we will be drawing a particular line such that the line will be able to map all the values
# - we will draw a line which will be able to capture maximum data points   and also we will find error present in it
# - how we will find out if the values are correctly predicted or not for this we drop a perpendicular from actual data point  to each data point to find out distance of the error  value
# - So line which has very less error that line will be treated as best line
# - So we will be create multiple line and the line which hs very less line we will chosse that line
# -

# %% [markdown]
# # Type of equation

# %% [markdown]
# ![10.JPG](attachment:10.JPG)

# %% [markdown]
# - We have three type of equation
#   - Linear
#   - quadratic equation
#   - Cubic equation
# - Linear equation has formula y = mx+c
# - if we have multiple varaiable then it will be like y = b1x1+b2x2+....+bnxn+b
#    - c = intercept
#    - m = slope value
# - Out of these we have to find out only value of coefficient i.e- b1,b2,b3,b4...

# %% [markdown]
# ![11.JPG](attachment:11.JPG)

# %% [markdown]
# - We have to make sure that the prediction which we are making are  a good prediction

# %% [markdown]
# **What are the feature of good prediction**

# %% [markdown]
# 1. model will gives accurate result
#
# model should give an accurate result the error should be minimum i.e the distance between actual data points and predicted data points should be minimum
#
# 2. The accuracy should not be limited to only one data points
#
# Let's say we are looking at a particular city for which we are trying to find out how much water or food is needed in that particular city and similarly we are looking for the multiple cities in the country so aur task is to find out the amount of food required as accurately as possible so that no city doesn't have extra food or no specific city has lesser amount of food . So we will have to make sure that all cities have suficient amount of food available so that no one will dies of hunger
#
# So here we can't do like we predict one requirement for one particular city correctly , and the prediction are very wrong or very inaccurate for the other cities because in that case other cities or the people who live in other cities would die of hunger
#
# So the prediction which we are making have to be in sync and accurate or good enough for all the data points or atleast for the maximum data points
#
# 3. The model which we will be making should be perform equally well on the testing data as well as on the training data
#
# let's take an example of preparing for exam
# so here we are preparing from a particular information or from particular book. Now this book is the entire portion material which we have , now what happen is the book will have certain questions at the end of the each and every chapter so when we are learning from this book we will practicing on those practice questions which we will be having at the end of the every chapter . So when we will be doind self evaluation , while we will be trainng ourselves to give exam ,we will be self evaulting ourselves on the basis of these practice question which are present at the back of the book  so we will be able to perform really well if we are studing hard , we will be able to perform really well on the training data that is the evaluation question or the practice question question which is in the book , So now the texting data is basically the exact exam in that exam we will have 14 question which will be not present in the book but will be based on the concept which are present in the book
# So when we are learning from the data , learning from the information which wis provided to us we want to perform well on the training data or on the practice question also but also we want to perform well on the final examination
# So this is what it means that it should perform equally well on the training data , that is a practice question and on the testing data which is the final evaluation so that it is good model
#
# 4. Simpler model is better model complex model is tends to overfit
#
# we want to make our model as simple as possible

# %% [markdown]
# ![12.JPG](attachment:12.JPG)

# %% [markdown]
# - regression is when we trying to predict a continuous variable
# - regression takes a group of random varaibel thought to be predicting y, and tries to find a mathematical relationship between them
#
# - So this relationship is typically inthe form of a straight line that best approximate all the individual data points
#
#
# let's say we have certain data regarding education and income so we want to set relationship between the education and the income of the person so that for the next time when someone tells us that this is their education , then we can easily guess what their income would be

# %% [markdown]
# ![13.JPG](attachment:13.JPG)

# %% [raw]
# - Predtive model is just like the application or just like box in which we provide our training data .So we will provide the training data , which is the independent input data and the dependent target values and we will provide to this box and then this box will try to decrypt the relationship between independent and dependent varaiable
# So it will try to establish a relatuonship between this and it will try to create a function internally   so that it will apply that function or it will apply that equation on the top of x values and using these equation it will be able to find out y-values
#
# So when we are training the model we are basically providing input data and output data , the input x values and the output values to the machine
#
# and machine will try to find out the pttern and relationship from the data which it has and create equation internally and then once this equation has been created then what happen is whenever we have  any other problem in hand or any other input data we can provide just input data to the machine and it will apply equation to this input data and automatically provide us the output value as prediction
#
# Now when we get output values or predicted values it will not be exactly equal to or same as the value which is expected
#
# So thsi gap or difference between the original value and what we have predicted is called error
#
# when we will add error for all the observation the result is called as cost value or the cost of the model
#
# cost value = sum of the all error
#
# So our target is to reduce the cost value
#
# here will reduce cumulative erro instaead of reducing the erro for just one value
# if we are reducing the value only for just one values in that case the error for other values migh increase so we don't want that we want to reduce overall error

# %% [markdown]
# ![14.JPG](attachment:14.JPG)

# %% [markdown]
# - Y= F(x)
#
# SO we have different x values , So out of those different x values , we want to find out a function which will give y as output
# so this function is actually linear equation which we will be forming
#
# - Y = b0+b1x1+b2x2+...+bnxn
#
#
# we know the value of x and y we have to find out the value of b0,b1,b2....

# %%
# So teh process is

# %% [markdown]
# ![15.JPG](attachment:15.JPG)

# %% [markdown]
# - Metrics are the type of measure which are used to evaluate the mdoels
# - let's say we are working in particular company we are making specific  kind of chemical or component in that case even a small millimeter or small amount of chemical cganges can changes the composition
# - now let's say we are working in salt packaging industry so that if we are dealing with gallon or tons of salts then small milligram of salts will not make a difference
# - so it is depending on the target value what exactly we are dealing with , the scale of the production will change the prediction will change
# - so if the production value is off by what even one milli the chemical industry it will cause issue but if the prediction will off even 5g or 10g in salt industry iw will not cause any issue so this is what goosness of prediction

# %% [markdown]
# ![16.JPG](attachment:16.JPG)

# %% [markdown]
# - whenwe add all the errors the sum comes out to be 10 but that doesn't means the error is only 10 actually the error value is 371 but because the value is canceled out with the negative and positive hence we have 10 value as error this is the reason we have to consider the absolute value

# %% [markdown]
# ![17.JPG](attachment:17.JPG)
