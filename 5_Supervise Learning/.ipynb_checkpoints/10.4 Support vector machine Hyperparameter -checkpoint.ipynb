# %% [markdown]
# # SVM Hperparameter

# %% [markdown]
# 1. Kernel

# %% [markdown]
# ![155.JPG](attachment:155.JPG)

# %% [markdown]
# - Kernel is mathematical function
#
# - this function of kernel is to take the data as input and transform it into the required form
#
# In below digram
#
# we have data which is in the form od 2d data , which is in two dimension x and y
# Now what kernel will do is kernel will transform this data from 2 Dimension to 3dimesnion where it will add another dimesnion z to it
#
# earlier x and y were 2 different dimension and the data had no linear seperation so we were not able to seperate these and we were not able to create a line between these
#
# Now with the presence of the kernel is what happen is kernel will transform this data from this 2 dimension to 3 dimension
#
# Now this 3 dimension will actually allows us to create a plane between x and z axis and this plane is able to seperate  both of these cluster
#
# Now when transform this data back to the linear plane, back to the x and y plane we can see that the line , the plane which we had all actually created had formed the circular plane which is able to classify x and y  and seperate x and y clearly

# %% [markdown]
# ![151.JPG](attachment:151.JPG)

# %% [markdown]
# - kernel defines the distance measure between new data and the support vectors i.e Observations closest to hyperplane
#
# so the kernel will make sure that the new data ,which we are adding to this particular data , the data which we are actually testing is evaluated w.r.t the  kernel , w.r.t the distance from the plane . So it is able tod find the distance and based on that , it can actually find out which observation which are closest to hyperplane and which are not
#
# The value which are closest to the hyperplane they are known as support vectors and based on the support vectors it actually defines the how the classification need to take place
#
# Now the main task here is how far or how close the lines could be to the support vectors
#
# That is the hyperplane which we are creating how far or how close can we allow them to get to the supprot vectors
#
# the closer the seperation line will be to this support vector , the more accurate the classification will be
#
# But anottehr thing is that there are a few more parameters which allows us to define these things

# %% [markdown]
# ![153.JPG](attachment:153.JPG)

# %% [markdown]
# - higher dimension kernel : Polynomial kernel and radial kernel transform the input space into higher dimension
#
# So there are the kenrels which are present for the lower dimesnion and there are the kernels which are present for higher dimension
#
# So Popynomial kernel and radial kernel are used for higher dimensions so they transform input space into higher dimesnion
#
#
# If we have linar kernel it will not transform the data into higher dimesnion it will just work on x and y axis
#
# But when we have polynomial kerenl it will allow to have more complex function and consider more complex function
#
# linear kernel will only create a straight line
#
# while polynomial and radial kernel will be able to capture the complex feature
#
# That is why for higher dimensional data we use polynomial and radial kernel

# %% [markdown]
# ![156.JPG](attachment:156.JPG)

# %% [markdown]
# Here we can see the visualization of the same , so here
#
# when we have linear kernel , we have a straight line of seperation which is needed . So here we have created a straight line and straight was able to classify the data accurately
#
# But when the data is actually in polynomial form That is it has different curves  in that case we can use polynomial kerenl
#
# and the situation where the pattern is alot more complex and cannot be figurred in single curve
# so in those cases we use radial Basis function
#
# in radial part we can see that we have small clusters of data seperater and these are still belonging to the same classes and around these we have another class so these are more acuurately classified by the radial basis function
#
# so how far the line of seperation will be is decided by another hyperparameter
#
# that is C- Value

# %% [markdown]
# ![157.JPG](attachment:157.JPG)

# %% [markdown]
# So what does the c value emphasize on
#
# c value emphasize on the distance from the support vectors
#
# so we have support vectors and hyperplane
#
# now if the value of the c is large then we will be trrying to have distance smaller
# and when the value of the c is small then we will try to maximize the distnace from the seperating hyperplane
#
# let's look at the image related to that

# %% [markdown]
# ![158.JPG](attachment:158.JPG)

# %% [markdown]
# so we can see that when c=1 the distance kept at very high
# when the distance is kept at very high so few of the datapoint actually fall inside this and these might get misclassified
#
# when we increase the value of c what happen is that the margin is kep very small and so that there is no point which gets misclassified
#
# so the larger the value of c the lesser the chance of misclasifcation

# %% [markdown]
# ![159.JPG](attachment:159.JPG)

# %% [markdown]
# If we have low value of gamma then datapoint will have very long impact for hyperparameter creation that is we have farther boundry
#
# when we have a high value of gamma , it means that we want to have hyperplane closer
#
# the higher the value of gamma the lower the radius will be or lower the radius of the influence will be

# %% [markdown]
# ![160.JPG](attachment:160.JPG)

# %% [markdown]
# In first digrm we have gamma is small so the radius of influence is high so we will try to kepp the boundry as far as possible
# that is why the boundry are straight in line and are farther away from the point
#
# while as the value of gamma increases , the points allow the boundry to be closer to them
# so because the impact of the point is low so it is allowing the type of hyperplane closer to it

# %% [markdown]
# ![161.JPG](attachment:161.JPG)

# %% [markdown]
# - It works well with a clear margin of seperations
#
# so in case we have data which has a clear space of margin where the classes are well seperated in those conditions SVM will work very well
#
# - It is effective in higher dimemnsional spaces
#
# because we have the kernels available which can actually deals with higher dimensions , then it is eefective in cases where the number dimesnions is greater than the number of samples
#
# let's sayw e have 20 datapoints and we have more number of dimensions (number of feature )
# so if we have more number of feature , there will be more number of dimensions availble
#
# now while classifying using SVM we are not really worried about all the data points which are present but only about the support vectors hence we really don't need that much amount of data
# in SVM there is no need to have large amount of data for have better performance
# for having a better performance we need a better , cleaner seperations that will be allowing to have better performance
#
# but more data or more number of rows of data hat would not really mean that we would have better classifier
#
# so it will work really well if it has high amount of dimesnion because if there are high amount of dimensions then it will aloows it to find those dimesnion where the data can actually be seperated
# because the kernels which we are using is acually being used to convert this data into higher dimesnion . Now when we have already higher dimesnion then it is easier task
#
# - It uses a subset of training points in the decision function (called support vectors) so it is also memory efficient
#
# because there is no need of all the data points we only need the support vectors that is why it is memory efficient in nature and it will be better performance and it will not be as complex as other algorithm

# %% [markdown]
# ![162.JPG](attachment:162.JPG)
