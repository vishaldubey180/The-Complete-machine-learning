# %% [markdown]
# ## Agenda

# %% [markdown]
# - Running jupyter notebbok
# - Input and output in python
# - Comments in python
# - data Types
# - variable
# - Numeric datatype

# %% [markdown]
# ### 1. Input and output in python

# %% [markdown]
# we use **input** keyword to take input from user

# %%
input("what is your name")
# Out:
# what is your namevishal
# 'vishal'

# %%
print(input("what is your name"))
# Out:
# what is your namemayank
# mayank

# %%
print('How are u')
# Out:
# How are u

# %%
print(5+10)
# Out:
# 15

# %%
print(30/5)
# Out:
# 6.0

# %% [markdown]
# ## Comment in python

# %% [markdown]
# we use "#" keyword to add comment

# %%
# adition
10+4
# Out:
# 14

# %%
'add'
13+9
# Out:
# 22

# %% [markdown]
# ## Data types

# %% [markdown]
# ![5.JPG](attachment:5.JPG)

# %% [markdown]
# ### Variables

# %% [markdown]
# variables is a placeholder which will hold  the particular values  and we can access those value by the variable name .

# %%
x = 7

# %%
x
# Out:
# 7

# %%
y = 3.1423

# %%
y
# Out:
# 3.1423

# %%
z = True

# %%
z
# Out:
# True

# %% [markdown]
# ![6.JPG](attachment:6.JPG)

# %%
print(x*y)
# Out:
# 21.996100000000002

# %%
x = 10

# %%
print(x)
print(type(x))
# Out:
# 10
# <class 'int'>

# %%
y = 3.14

# %%
print(y)
print(type(y))
# Out:
# 3.14
# <class 'float'>

# %%
#addition
x+y
# Out:
# 13.14

# %%
x-y
# Out:
# 6.859999999999999

# %%
x*y
# Out:
# 31.400000000000002

# %%
x/y
# Out:
# 3.184713375796178

# %%
x//y
# Out:
# 3.0

# %%
9//4
# Out:
# 2

# %%
9%4
# Out:
# 1

# %%
#power

3**5
# Out:
# 243

# %%
 8**(1/3)
# Out:
# 2.0

# %%
4**0.5
# Out:
# 2.0
