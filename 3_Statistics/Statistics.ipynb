# %% [markdown]
# ## STATISTICS

# %% [markdown]
# - The science and the art of learning from data
# - it is
#   - the collection , analysis and interpretation of data
#   - the effective communication and presentation of results relying on data

# %% [markdown]
# Population
# - population is the entire dataset which we have
#
# sample
# - sample is a small part or subpart of the population
# - it is selected randmoly
# - we use the samples and analyze the samples tod erive infrences regarding the populations

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %% [markdown]
# - Mean of population is true representaion
# - mean of sample may or may njot be exctly equal to population it may contain some error

# %% [markdown]
# # Sampling technique

# %% [markdown]
# - so when we are taking samples we have to apply several sampling technque
#  - there are two type sampling technique which are available
#     - Probability Sampling
#     - Non probability sampling

# %% [markdown]
# ### Probability Sampling
#
# - It involves random selection allowing us to make statistical infences about the whole group
# - sampling is done by random selection of elements from population

# %% [markdown]
# ### Non- Probability Sampling
#
# - It involves non- random selection based on convenience or other criteria allowing us to easily collect initial data

# %% [markdown]
# ![3.JPG](attachment:3.JPG)

# %% [markdown]
# ### Type of Probability sampling

# %% [markdown]
# #### 1.Simple random sampling
#
# - In this we take random value from the entire set, we pickout random elemnts from the entire set

# %% [markdown]
# #### 2. Systematic sampling
# - in this type of sampling we systematically pick a particular sequence of values from the entire data
# - ex: let's say we have value from 1 to 20 so we are picking up all the even data or multiple of 3

# %% [markdown]
# #### 3.Stratified random sampling
# - the stratified sampling has the values big doubt, a clear cluster has formed
# - different cluster have been formed from the data
# - ex: cluster of old and young men have been taking seperately, another cluster of woman have been taken seperately and the cluster of children have been taken seperately
# - and from these clusters people are picked out seperately

# %% [markdown]
# #### 4.Cluster sampling
#
# - In this we create clusters out of entire data
# - we create different clusters from the data and we just pick out one cluster from the entire data and we use them for samples

# %% [markdown]
# ![4.JPG](attachment:4.JPG)

# %% [markdown]
# ## Desciptive Statistics

# %% [markdown]
# ![5.JPG](attachment:5.JPG)

# %% [markdown]
# - A descriptive statistics is a summery statistics that  quantitatively describe or summerize the data
# - while descriptive statistics is the process of using and analyzing those statistics
# - whenever we want to quantitatively summerize the data , we use the descriptive statistics
# - we don't want to find out something from the data
# - we just want to summerize the data
# - this is called desciptive statistics

# %% [markdown]
# ## Measures of central tendency

# %% [markdown]
# ### Mean
#
# - A calculated central value of a set of numbers
# - Add all the numbers and divide by the count of number added

# %% [markdown]
# ### Median
#
# - The middle number in a sorted acending or descnending,
# - list of the median is something used as oppose to the mean when there are outliers in the sequence that might skew the average of the values

# %% [markdown]
# ### Mode
#
# - the mode of a set of data values is the value that appears most often
# - it is the value that is  most likely to be sampled

# %% [markdown]
# ![6.JPG](attachment:6.JPG)

# %% [markdown]
# ![7.JPG](attachment:7.JPG)
