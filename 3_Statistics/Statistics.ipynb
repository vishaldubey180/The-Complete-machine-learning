# %% [markdown]
# ## STATISTICS

# %% [markdown]
# - The science and the art of learning from data
# - it is
#   - the collection , analysis and interpretation of data
#   - the effective communication and presentation of results relying on data

# %% [markdown]
# Population
# - population is the entire dataset which we have
#
# sample
# - sample is a small part or subpart of the population
# - it is selected randmoly
# - we use the samples and analyze the samples tod erive infrences regarding the populations

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %% [markdown]
# - Mean of population is true representaion
# - mean of sample may or may njot be exctly equal to population it may contain some error

# %% [markdown]
# # Sampling technique

# %% [markdown]
# - so when we are taking samples we have to apply several sampling technque
#  - there are two type sampling technique which are available
#     - Probability Sampling
#     - Non probability sampling

# %% [markdown]
# ### Probability Sampling
#
# - It involves random selection allowing us to make statistical infences about the whole group
# - sampling is done by random selection of elements from population

# %% [markdown]
# ### Non- Probability Sampling
#
# - It involves non- random selection based on convenience or other criteria allowing us to easily collect initial data

# %% [markdown]
# ![3.JPG](attachment:3.JPG)

# %% [markdown]
# ### Type of Probability sampling

# %% [markdown]
# #### 1.Simple random sampling
#
# - In this we take random value from the entire set, we pickout random elemnts from the entire set

# %% [markdown]
# #### 2. Systematic sampling
# - in this type of sampling we systematically pick a particular sequence of values from the entire data
# - ex: let's say we have value from 1 to 20 so we are picking up all the even data or multiple of 3

# %% [markdown]
# #### 3.Stratified random sampling
# - the stratified sampling has the values big doubt, a clear cluster has formed
# - different cluster have been formed from the data
# - ex: cluster of old and young men have been taking seperately, another cluster of woman have been taken seperately and the cluster of children have been taken seperately
# - and from these clusters people are picked out seperately

# %% [markdown]
# #### 4.Cluster sampling
#
# - In this we create clusters out of entire data
# - we create different clusters from the data and we just pick out one cluster from the entire data and we use them for samples

# %% [markdown]
# ![4.JPG](attachment:4.JPG)

# %% [markdown]
# ## Desciptive Statistics

# %% [markdown]
# ![5.JPG](attachment:5.JPG)

# %% [markdown]
# - A descriptive statistics is a summery statistics that  quantitatively describe or summerize the data
# - while descriptive statistics is the process of using and analyzing those statistics
# - whenever we want to quantitatively summerize the data , we use the descriptive statistics
# - we don't want to find out something from the data
# - we just want to summerize the data
# - this is called desciptive statistics

# %% [markdown]
# ## Measures of central tendency

# %% [markdown]
# ### Mean
#
# - A calculated central value of a set of numbers
# - Add all the numbers and divide by the count of number added

# %% [markdown]
# ### Median
#
# - The middle number in a sorted acending or descnending,
# - list of the median is something used as oppose to the mean when there are outliers in the sequence that might skew the average of the values

# %% [markdown]
# ### Mode
#
# - the mode of a set of data values is the value that appears most often
# - it is the value that is  most likely to be sampled

# %% [markdown]
# ![6.JPG](attachment:6.JPG)

# %% [markdown]
# ![7.JPG](attachment:7.JPG)

# %% [markdown]
# - presence of even one outlier cause a very huge change in the value of mean
# - So we can not really explain the sequence using the mean because when we see the mean of these values  is 13.5, we are kind of seeing that the median value is between 12 and 100 which is not correct
# - majority of the values which are lying from 1-12 shuld have mean around 5.63
# - so this is the reason why we can not really use these measures of central tendency to explain much
# - When the value such as the mean is calculated in presence of an outliers , it can not reallypict the measure of central tendency more .
# - so particular in this situation we will try to explain the sequence or rxplain the data by using the **median** value
# - Because the median value will not be impacted by outliers
# - so when outliers will added in data still there is no much change in median value

# %% [markdown]
# ### Which value to use when

# %% [markdown]
# ![8.JPG](attachment:8.JPG)

# %% [markdown]
# ## Measures of variablity(spread)

# %% [markdown]
# - Mean, median, mode can provide information about the central point of the data but do not tell about how data varies .
# - Range
# - IQR
# - VARIANCE
# - STANDARD DEVIATION

# %% [markdown]
# ## Quartiles and interquartiles range

# %% [markdown]
# ![9.JPG](attachment:9.JPG)

# %% [markdown]
# - Quartiles are basically the data that divided into four parts (quarters)
# - So here the data from 3 to 7 is first quarter which is the 25% of the values
# - Then 8-11 is the next 25% of the values
# - then 12-15 is the next 25% of the values
# - then 17-20 is the next 25% of the values
# - the value from 3- 11 means 505 of the values and 12- 19 means next 50% of the values
# - First quartile is named as Q1
# - second quartile is named as Q2
# - Third quartile is named as Q3
# - InterQuartile range is the difference between Q3 and Q1
# - Q3-Q1 = 17-7 = 10
# - To find out if a vlaue is outliers or not we have formula
# - Q1-1.5*IQR = 7-15 = -8
# - Q3 + 1.5*IQR = !6+15 = 32
#
# - Any value above 32 will be an outlier and any value below -8 will be outlier

# %% [markdown]
# ![10.JPG](attachment:10.JPG)

# %% [markdown]
# - In above digram we have boxplot

# %% [markdown]
# ## STAANDARD DEVIATION AND VARIANCE

# %% [markdown]
# ![11.JPG](attachment:11.JPG)

# %% [markdown]
# - we have calculated mean of the vaues which is nothing but 8.4444
# - Now we will find out the deviation of the numbers from the first numbers
# - then we find out the deviation form the last number
# - then deviation from the mean
# - Squared deviation from the mean
# - here we can see all the values are very close to each other

# %% [markdown]
# ![12.JPG](attachment:12.JPG)

# %% [markdown]
# - In above example we have modifed the last value from 16 to 59
# - that means we have added outliers
# - Now let's do same calculation
# - we have calculated mean of the vaues which is nothing but 13.22222
# - Now we will find out the deviation of the numbers from the first numbers
# - then we find out the deviation form the last number
# - then deviation from the mean
# - Squared deviation from the mean
# - here we can see all the values are kind of different from each other

# %% [markdown]
# ##### Now let's calculate the same thing with outlier at the lower end

# %% [markdown]
# ![13.JPG](attachment:13.JPG)

# %% [markdown]
# - Consider this when an ouliers is introduced the deviation from the first number and the last number is varing alot
# - these values are not matching enough
# - But when there are no outliers these values are matching
# - This mean the deviation from the first number and the last number is not able to capture the devuation  properly
# - so these are not able to capture the variance in the data properly
# - so what we here do is we consider the deviation from the mean and because the deviation from the mean always comes out to be near zero
# - so we use squared deviation from the mean
# - so when we use squared deviation of the mean and calculated the variance out of it , it gives us more robust value which could explain the data properly
#
# - Hence we use varaince

# %% [markdown]
#  **Variance**
# - In probability theory and statistics variance is the average of the squared difference from the mean
# - Informally , it measures how far a set of numbers are spread out from their average value.

# %% [markdown]
# ![14.JPG](attachment:14.JPG)

# %% [markdown]
# - there is difference between those two formula
#   - in case of pupulation we use n in the denominator
#   - while in case of samples we use n-1 in the denominator

# %% [markdown]
# **Standard deviation**
# - It is the squared root of the variance

# %% [markdown]
# ![15.JPG](attachment:15.JPG)

# %% [markdown]
# - When we are calculating sample variance or standard deviation we are using n-1 instead of n
# - this is because of Besels correction

# %% [markdown]
# ### Bessels correction

# %% [markdown]
# - Bessels correction refres to the the n-1 found in several formulas , including the sample variance and sample standard deviation formulas . thuis correction is made to correct for the fact that thses sample statistics tend to underestimate the acual parameter found in the population
# -  The Standard deviation And variance which we are calculating for the sample is kind of not considering the entire picture and might be little lowe than the actual variance and standard deviation of the population
# - so what we do is we reduced the value in the sample so that when we reduce the denominator the entire value of the variance and the standard deviation kind of increase a little so it balances out and makes it closer to the population standard deviation and population varaince

# %% [markdown]
# ### Shapes of distribution of the data

# %% [markdown]
# -  A data **distribution* shows all the possible values of the data and how often each value occurrs
# - For **Normally distributed**. the mean , median and mode are all equal and therefor are all appropriate measure of central tendency
# - for **Skewed** the median may be a more appropriate  measure of central tendency

# %% [markdown]
# ![16.JPG](attachment:16.JPG)

# %% [markdown]
# ## Normal distribution

# %% [markdown]
# - **Normal Distribution** some times called the bell curve is a distribution that occurs naturally in many situations for ex. the bell curve is seen in scores of students . the bulk of the students will scores the average (c), while smaller number of student will score B or D . An even smaller percentage of students score an F or an A . This create a distribution that resembles a bell
# - The bell curve is symmetrical. half of the data will fail to the left of the mean; half will fail to the right
# - Many groups follow this tytpe of pattern . that is why it is widely used in business statistucs

# %% [markdown]
# ### Characterstics of bell curve

# %% [markdown]
# - Created from the parametrs
#  - mean
#  - Standard deviation

# %% [markdown]
# can be followed for various purpose be like :
#     - scholarship distribution
#     - finding the best performer or worst performer
#     -finding a segment of data

# %% [markdown]
# ![17.JPG](attachment:17.JPG)

# %% [markdown]
# - In above digram we have bell curve and data is normally distributed
# - Most number of student will have C rating
# - there will be few student who will have B or D
# - And there are very few student who will have A or F
# - let's say we have to ditribute
# - What we can do is we can filter out the students on the basis of top most rating
# - So this has a distribution where the middle most area , which is the eman value plus one standard deviation and minus one standard deviation , this area contain 68%of the data
# - while mean plus 2 Standard deviation and mean minus 2 standard deviation contain 94.45% of the data
# - And mean - 3SD, mean +3SD contain 99% of the data
# -  So we can give the  scholarship to students who have scored more than mean plus 2 Standard deviation
# - OR Let us say we want to fire people from the organisation then we can put the people from getting less than mean minus two standard deviation into the monitoring zone , we can monitor the performance of the people at work

# %% [markdown]
# ## Kurtosis

# %% [markdown]
# - **Kurtosis** is a statistical measure thatd efine how heavily the tails of a distribution differ from the tails of a normal distribution
# - **Kutosis** identifies whether the tails of a given ditribution contain extreme values

# %% [markdown]
# ![18.JPG](attachment:18.JPG)

# %% [markdown]
# ## Skewness

# %% [markdown]
# - Skewness refres to distortion or asymmetry in a symmetrical bell curve, or normal distribution , in a set of the data
# - if the curve is shifted to the left or to the right , it is said to be skewed
# - skewness can be quantified as a represntation of the extent to which a given distribution varies from a normal distribution
# - A normal distribution has a skew of zero

# %% [markdown]
# ![19.JPG](attachment:19.JPG)

# %% [markdown]
#  - A Normal distribution has no skew so for thus mean , median and mode will be the same value and this is the perfectly symmetrical distribution
# - Then we have negaitively skewed it is skewed towards the negative direction, towards the left direction
# - Then we have Positively  skewed it is skewed towards the positive direction, towards the right hand direction
# - In negative skewed mode will be higher than median and median will be higher than mean value
# - while  in Postive  skewed mean will be higher than median and median will be higher than mode value

# %% [markdown]
# ## Correlation and Covariance

# %% [markdown]
# - Bothmeasure the **relationship** and the **dependency** between two variable
# - **'Covariance'** indicates the direction of the linear relationship between variable
# - **'Correlation'**  on the other hand measures both the strength and the direction of the linear relationship between variable

# %% [markdown]
# - Let's say we have two variable age and income of person
# - In ideal situation as the age of the person increase income will also increase so here there is the positive relationship between the age and income
# - while we talk about age and health of the person as the age of the person will increase the health of the person will decrease so there is negative relationship between age and health

# %% [markdown]
# ![20.JPG](attachment:20.JPG)

# %% [markdown]
# ## Infential Statistics

# %% [markdown]
# **Descriptive Statistics**
# -It consist of the collection organization summerization and the presentation of the data (it describe the situaion as it is)

# %% [markdown]
# **Infrential statistics**
# - It consist of making infrences from samples to populations , hypothesis tetsing , determining relationship between variables and making predictions (it is based on probability theory )
# - In case of infrential statistics we will be taking up a sample and based on that sample we make infrences regarding the population data because usually we will not be able to find out everything about the population, Finding out the measure regarding the population is very tedious task
# - For example we are talking about salaries of all the people in the world , Now calculating the salaries for all the people in the world will take lot of time so instead of calculating and summing up the salaries of all people of the world what we do is we take small sample of people from all the world and based on these samples we try to predict we try to find out salaries which will be belonging to the all the people of the world so this is what infential statistics is
# - we will have some sample data and based on the sample data we will try to find out about the population
# - again we will try to compare different samples and find out if they belong to the population or not and if there is some relationship between these two samples  or not  so these kind of things , which when we do those are called infrential statistics

# %% [markdown]
# ### Why we need Infrential statistics

# %% [markdown]
# - Descripive statistics describe the data
#
# - infrential Statistics allows us to make prediction(infrences) from the data
# - With infrential statistics we take data from samples and generalize about the pupulation
# - we can take mean of the samples and then try to find out what would be the mean of the population
# - For exaple we have bit of sample of people who are diabetic , so from their diabetes level, i can find out about the diabetes level of people all around the population

# %% [markdown]
# - ** Infrential statistics provide a way of going from a "sample" to "population" inferring the parameters of a population from data on the statistics of the smaple
# - ** it is necessary for a researcher to work with samples rather than a whole population . But one difficulty is that a sample is generally not idnetical to the population from which it comes.
# - ** Another difficulty is that no two samples are the same . how can we know which best describe the population? we need rules that relate samples to populations

# %% [markdown]
# ## Estimation Techniques

# %% [markdown]
# - There are two different approaches for estimating
#      - Point Estimation
#      - Interval estimation
#
# - **For Point Estimation** w egive one value for a characterstics, which is hopefully close to the true unknown value
# - we can not expect to find the precise value describing the population when only using data of a samples
#
# - **For interval Estimation** we give an interval of likely vlues , where the width of the interval depends on the confidence we require to have in this interval
#
# - So in caes of point estimation it will try to provide a value of the mean or it will try to provide a value of standard deviation and based on the standard deviation we are not really sure if the standard deviation of the smaple will actually be the standard deviation of the population or the mean which we have calculated for the samples will actually be the mean of the population because the samples are generated randomly teh values in the samples would differ so mean will defer each and every time
# - So we need to find out a value which would be excatly similar to the population or which is as close as possible to the population
# - So we cannot actually expect to find the precise value describing the population when only using data of samples
# - so when we rae finding out some poit estimation from the sample, we can not completely sure that the sample mean, which we have calculated will always be equal to the population
# - this is something which we can very easily say because we rae not sure how the sample has been generated and if this sample actually represent the population so we need to calculate and find out several samples and from those several samples we will have to find out the mean which will actually justify the population mean .
# - So we can not see about a population from just one single sample
#
# **So what we do now **
#
# we have another method
#
# -**Interval Estimation**
# - Interval estimation gives an interval of likely values
# - So instead of saying the eman is 20 it will say the mean value for the population lies between 18 and 22 and i am 90% sure that it will be correct or i am 90% sure that this value is always correct
# - This means if we do sampling for 100 times then there is chance of 95% that mean will be between 18-22

# %% [markdown]
# ## Caution

# %% [markdown]
# - Statistics NEVER prove anything instead they indicate a relationship within a given probability of error
# - An association does not necessarily indicates a sure cause effect relationship
# - statistics can always be wrong , however there are things that researcher can do to improve the likelihood that the statistical analysis is corrcetly identifying a relationship between varaiable

# %% [markdown]
# # Variable Types

# %% [markdown]
# **Qualitaive Vraiable**
#
# - No mathematical meaning or non numeric varaiable that can be placed into distinct categories according to some characterstics or attribute . (ex gender, religious preference, geographic location, grades of students car's tags etc)
#
# **Quantitative variable
#
# - Numerical in nature and can be ordered or ranked (ex age, heights, weights body temperature etc)
#
# **Two type**
#
#    - **Discrete Variable**
#
#       - Assumes values that can be counted such as whole numbers (ex the numbers of the children in the family. the number of the studnet in the classroom , the numbers of the calls received by switched by a switchboard operator each day for one month etc.
#
#    - **Continuous variable**
#       - can assume all values between any two specific values by measuring (ex temperature,height,weight,time,speed stc)

# %% [markdown]
# ## MEASUREMENT SCALE OF THE DATA

# %% [markdown]
# ![21.JPG](attachment:21.JPG)

# %% [markdown]
# ## Nominal Data
#
# - It is catagorical data which will have no order no mathematical meaning
# - they have no order or ranking with them
#
# ## Ordinal
#
# - Ordinal type is where we have particular order present but there is no specific or equal distance is not present in them
# - ex: grades a b and c, if student score more than 90 then he will get A, if more than 80 then he will get B, if more than 60 then he will get C, if less than 70 then he will get D
#
# ## Interval
#
# - Interval have weual distnace between them but they will not be a specific zero value associated (ex hours of the day there is not zero hours it starts from 12 to 12 , there is no 0th day there is always 1st day of the month
#
# ## Ratio
#
# - The ratio values are those which have zero associated with it and order is also present (ex height , weight, salary)

# %% [markdown]
# ## Symbol and meaning

# %% [markdown]
# ![22.JPG](attachment:22.JPG)

# %% [markdown]
# # Central Limit Theorem

# %% [markdown]
# ### 1.**Frequency distribution**
#
# - it gives the exact **frequency** or the number of the times a data point occurs
#
# ### 1.**Probability distribution**
#
# - it gives the  **Probability** of the occurence of the given data point

# %% [markdown]
# - When the number of test cases are large the **frequency distribution** and the **probability distibution** are similar in shape

# %% [markdown]
# ![23.JPG](attachment:23.JPG)

# %% [markdown]
# - In above digram the dataponit ranges from 10 -18
# - and frequency(number) of each data point is given
# - total number of datapoint is 50
# - 16 is occuring 14 time hence mode of the data is 16
# - relative frequency give probability of number occuring
# - frequency helps us to find out probability of data occuring
# - there is 4% chance that 10 will occure
# - there is 6% chance that 11 will occure  when we take sample out of this data and so on

# %% [markdown]
# - We can plot this to get frequency distribution and probabiity distriution
# - So when we plot the frequency distribution the area under  the frequency distribution actually provide probability of value occuring

# %% [markdown]
# ![24.JPG](attachment:24.JPG)

# %% [markdown]
# HII
#
# HOW are
#
# You

# %% [markdown]
# - So in above digram we can see the frequency distribution plot where the frequency of evry value is given  from 0-22
# - out of this probability  dirtribuiton plot i created which is the line of curve  which will give the probability of a particular vaue of ocuuring
# - if we want to find out the the probability of one occuring then we can find out the area below the one and it will give probability of ocuuring one
# - similarly if we want to find out the probability of value ocuuring between a and b then we can find out area below the curve between A and B

# %% [markdown]
# ## The distribution of sample Means

# %% [markdown]
# - **Defination::** The distirbution of sample means is the collection of smaples means for all the possible random samples of a particular size(n) that can be obtained from populations( so here we are collecting lot of sample let's say we collected 100 samples from those hundred samples we calculated means   we takout those means and then we plot these means together so we collect the sample means for all the possible random sample of a particular size n . so the sample which we will be taking from the population will have common size , so size will be same  and because the smaple will be taken randomly then the value in the sample will be different so because the value of the sample will be different , the mean value will also be different for all the sample  so we can obtain these sample and the mean from the population and then we can plot them together )
#
#
# - It is not a distribution of scores , but a distribution of statistics(because we are not taking the ema of the entire population , we rae not taking values from the entire population , we are only plotting the means of all samples  now when we do this what happen the distribution will be kind of in normal form , why in normal form? let's say we are taking different samples from population and vaue of population ranging from 1-100, so now when we take out sample the sample vaue will be arandomly from 1-100, and when we take mean os samples it may not be always equal sometimes it may be 50 sometimes 51 sometimes 52 etc)
# - the distribution tend to be nromal
# - it will be almost perfectly normal if either :
#     - the ppulation from which the sample is drawn is normal or
#     - the n of the sample is relatively large (30or more). The distribution has a mean that is equal to the population mean

# %% [markdown]
# # Properites of normal curve

# %% [markdown]
# - A normal distribution curve is bell- shaped
# - The mean median and mode are equal and are located at the centre of the distribution
# - The normal distribution curve is Unimodal(i.e it has only one mode )
# - the curve symmetric about the mean which is equivalent to saying that it's shape is the same on both side of a vartical line passing through the center
# - the curve is continous that is that is there are no gaps or holes for each value of x , there is corresponding value of y
# - The curve never touches the x - axis . theoretically no matter how far in either direction the curve extent it never meets x-axis but it get's increasingly closer
# - the total area under a normal distribution curve is equal to 1 or 100%
# - Area under curve gives the probability of a point falling in the area

# %% [markdown]
# ![25.JPG](attachment:25.JPG)

# %% [markdown]
# ![27.JPG](attachment:27.JPG)

# %% [markdown]
# - So this is Population  distribution
# - For the above curve the mean =0.12 and SD of x =20.06
# - Now what we will do we will take several samples  from above population distribution
# - the value of samples will range from -100 to 100

# %% [markdown]
# ![28.JPG](attachment:28.JPG)

# %% [markdown]
# - We can see that in samples the distribution are differet
# - there are different distribution of samples they are not exactly same samples
# - standard deviation of each samples is different
# - Now all sample will have some mean value , mean will also be different
# - So what happen when we take 500 or two hundred or any number of samples then we create the sampling distribution out of it which is tye distribution of the sample means

# %% [markdown]
# ![29.JPG](attachment:29.JPG)

# %% [markdown]
# - So here we have created a plot of all the means of samples
# - This plot is plot of means

# %% [markdown]
# - So here we have taken  160 random samples and taken out there mean and plotted them here
# - Each sample consist of 103 observation
# - So here n value is 103 and the number of sample is 160

# %% [markdown]
# - From this sampling distribution the mean is 0.08
# - The population mean 0.12

# %% [markdown]
# ***Central Limit theorem***

# %% [markdown]
# - **It states that The distribution of sample means(the sampling distribution ) should be nearly normal**
# - **AND**
# - **The meaan of the sampling distribution should be approximately equal to the population mean (0.12)**
# - **Standarad error is the standard deviation of the sampling mean**
# - **SE = SD/SQRT(N) => (20.02/sqrt(103) = 1.98**

# %% [markdown]
# # Z-Score

# %% [markdown]
# - **Standard scores or z-scores**- a comparison of a relative standard like both(the mean and standard deviation) can be made
# - number of standard deviation a data is above or below the mean for a specific distribution of the values
# - Z - score is a very useful statistics because it allows us to calculate the probability of a score occuring within our normal distribution
# - It enable us to compare two scres that are from different normal distribution
# - If a z score is 0 It indicate that  data point score is identical to the eman score
# - A Z-score of 1.0 will indicate a value that is one standard deviation from the mean
# - A  score may be +ve or -ve. With +ve value indicate that the score is above the mean and -ve value indicate that the score is below the mean

# %% [markdown]
# ![30.JPG](attachment:30.JPG)

# %% [markdown]
# - Let's say we have a particular data set , dataset have some distribution present in it
# - Now in that particular dataset or sample if we want to find out location of the particular data point Or we want to find out how far a datapoint is present in terms of standard deviation or mean
# - that is something which is provided by z-score
# - So z- score is a number which we calculate and then we match that value in z- Table which give us a probability value
# - Probability value provide us the probability of the value being present in the plot

# %% [markdown]
# ![31.JPG](attachment:31.JPG)

# %% [markdown]
# - Let's say we have above distribution and we want to find out the location of the 0.8 in terms of mean of this distribution then we can find out this on thhe basis of z-score value
# - SO based on z - score we can find out what is the probability of particular value occuring in the distibuiton

# %% [markdown]
# - Value of z score range from **0-1**

# %% [markdown]
# ![32.JPG](attachment:32.JPG)

# %% [markdown]
# ###### here the mean score will have the value as zero
# ###### Now if the z-score value is towards the one or grater than zero that means that means data points is actually lying towards the right hand side of the knee
# ###### Now if the z-score value is towards the -one or less  than zero that means that means data points is actually lying towards the left hand side of the knee
# ###### ANd it is calculated as a part of normal distribution only
# ###### When we are calculating z- score we are assuming that the distribution is actually a normally distribution
# ###### And because the distibution is normal and symmetrical
# ###### ANd let's say we have a value of z = -0.75 and when we look  probability for this value in z table .
# ###### And we got probability 0.2266 that means  the area below that point has 22% of the data in normal distribution

# %% [markdown]
# # Z-score standarisation

# %% [markdown]
# - It is use to scale the data so that all the variable have same range
# - Ex age and salary
# - for standard normal distribution the mean is 0 and standard deviation is 1

# %% [markdown]
# ![33.JPG](attachment:33.JPG)

# %% [markdown]
# - So here we have column age and salary
# - and we can see that the range of age and salary is very different
# - age is 20-52 and salary is 20K 0 50K
# - So in case if we want to find out that what is the probability of having this age with respect to the salary . It is difficult to find out  because scale is different
# -  so we can scale the age and salary with the help of z-score
# - And when we scale age and salary using z-score the standard deviation will be 1 and mean will be 0 for both of the column

# %% [markdown]
# #### Finding Probability(area under curve ) for a normally distributed variable by transformingit  into a standard normal variable by using formula of z-score

# %% [markdown]
# ![31.JPG](attachment:31.JPG)

# %% [markdown]
# - Here we find out the value of z score is 0.80
# - Now we will look this value in z-table

# %% [markdown]
# ![34.JPG](attachment:34.JPG)

# %% [markdown]
# - Z table represent the area to the left side of the z score
# - so here we have z score 0.8 now  we want to find out area below 0.8
# - We go to the table we look for the value of 0.8
# - so the value is 0.78814
# - 0.78814 is the percent of data less than 3.5 hours

# %% [markdown]
# ## Next problem

# %% [markdown]
# ![35.JPG](attachment:35.JPG)

# %% [markdown]
# - So here mean value is 28
# - Standard deviation is 2
# - In graph at 0 the mean will be 28
# - we have to find out the percentage of data between 27 and 31
# - we find out the z value for 27 which is -0.5
# - then z value for 31 which is 1.5
# - Now we want to find out the area between 27-31
# - Now we will look the value in z table for the z score -0.5 and 1.5
# - and then we will subtract it

# %% [markdown]
# ![36.JPG](attachment:36.JPG)

# %% [markdown]
# ![37.JPG](attachment:37.JPG)

# %% [markdown]
# - WE get the value as 0.6247
# - That means value between 27 and 31 is 62%

# %% [markdown]
# ### FInding specific data values for given percentage using the standrad normally distribution

# %% [markdown]
# ![38.JPG](attachment:38.JPG)

# %% [markdown]
# - The top 10% of data is given
# - 10% means 0.10

# %% [markdown]
# ![39.JPG](attachment:39.JPG)

# %% [markdown]
# ![40.JPG](attachment:40.JPG)
