# %% [markdown]
# # Dimesnionality Reduction

# %% [markdown]
# ![31.JPG](attachment:31.JPG)

# %% [markdown]
# - dimensionality reduction helps us in reducing the number of columns and appropriately feature selecting
#
# - Now feature selection and dimensionality redution do the same thing , but in different way
#
# because in case of feature selection we already have several column and several attriute , but we only have to select some of them and drop other columns from the daatset
#
# but in case of dimensionality reduction we completely transformed the datset from let's say 100 or 300 columns to a different data set of smaller number of columns (ex 12 or 50 columns )
#
# Now the amount of information which will be present in the original dataset with 100 or 300 column will be similar to the amount of information which we will get after the transformation using dimensionality reduction
#
# so in feature selaction we used toselect a few feature from the entire dataset
#
# while in dimensionality reduction we convert the data into a new fresh dataset where we have the same amount of information
# the information which we have in the original data is intact , but the number of columns has now reduced
#
# Now because the number of columns has reduced , it is less complex to use them , and it also reduced the time consumed for training different models

# %% [markdown]
# ![32.JPG](attachment:32.JPG)

# %% [markdown]
# Feature enginerring is the process of creating features so that we can use them for ML algo training
#
# so feature selection is actually one part of feature enginerring where we actually select different feature from all the feature which are already present

# %% [markdown]
# ![33.JPG](attachment:33.JPG)

# %% [markdown]
# . Incomplete data with a few features - led to the development of the common myth
#
# so when we have incomplete data and when we have few features , then we think that our model is not working fine because we have less amount od deatils , we have less amount of features
# But that is not true
#
# having less number of features is not problem
# having features which does not have good information , good quality of information is the problem
#
# so having more feature and more data will always improve the accuracy of solving the ML problem
#
# so this is the myth which is there
#
# but in reality it is curse more than gain
#
# lot of features with few datapoints . Fitting the model in this scenario often leads to a low accuracy model even with many features - called  as the curse of dimensionality
#
#
#
# so basically we don't want to have such large features because we want to have smaller feature space , some good feature which will be able to explain the problem , which will be able to represent the actual information instaed of having irrelevant to 100 or 300 columns which don't really help and only inrease the complexity and time we don't want that
#
#
# we want only some good quality features

# %% [markdown]
# ![34.JPG](attachment:34.JPG)

# %% [markdown]
# ![35.JPG](attachment:35.JPG)

# %% [markdown]
# ![36.JPG](attachment:36.JPG)

# %% [markdown]
# let's say we have a problem where we are recording the motion of spring
#
# so there is one spring or pendulam which moves in a direction
#
# now in this motion if someone is not really aware of where they should check this particular motion
# what they will do is they will apply different cameras at different angles
# and now applying different cameras at different angles will not really help
# so if someone knows where the cameras has to be , then will apply three cameras and actually will be able to capture the motion
# but if someone is not aware of the exact direction of motion , then they might be applying a number of cameras to record the moment wit at least 3 cameras
# the we will play some different cameras in case we don't know what cameras we need to apply
# so we will keep adding cameras to cpture the motion but we will not be able to capture the motion entirely or we will nedd a lot more number of cameras to capture the motion if we don't really know that we need to spply these camera at 90 degree angles with each other
#
# so we get from this is that a cameras at 90 degree angle will be able to capture more information in comparison to cameras placed at different locations
#
# so the same thing what we do in the PCM

# %% [markdown]
# ![37.JPG](attachment:37.JPG)

# %% [raw]
# - So PCA transform our feature(or cameras) into a new dimesnional space and represents it as a set of new orthogonal variables(orthogonal variables are variables which are perpendicular to each other ) so that our problem is observed with a reduced set of features
#
# so we already had a feature space which had multiple dimesnions but all of these dimesnsions were capturing the data in different ways
# but because these dimensions were not really at the 90 degree angle and they were not able to capture much information
# now what we did we applied PCA and using PCA we created another dimension , another dimesnion space where all dimension are at 90
# now these 90 degree angle were able to capture more information from different dimensions then they were actually able to capture
#
# so these orthogonal feature are actually called principal components
#
#
#
# Now in practice our data is like the motion of the pendulum . If we had complete knowledge of the system , we will require the less number of features
#
# we have to observe the system using a set of features which will convey maximum information ifthey are orthogonal . this is done using PCA
#
#
# the new set of features which are produced after PCA transformation are linearly uncorelated(Independent on each other ) as they are orthogonal . morever the feature are arrnged in decreasing order of their importance
#
# we will get these features in sorted orders
# let's say we will get 10 principal components out of 100 principal components
# now it will be sorted in the orders where the first will be able to capture maximum amount of information
# then 2nd
# then 3rd and so on
#
# so we can seelct top5 or top7 which will be able to capture most of the information

# %% [markdown]
# ![38.JPG](attachment:38.JPG)

# %% [markdown]
# ![39.JPG](attachment:39.JPG)

# %% [markdown]
# Let's say we have 100 columns which will give 100% of data
# now we ahve applied PCA and we have received these some principal components
# so each of this principal components will be able to explain some variance(amount of information )
#
# first component will be able to capture 40% of information
# next almost 20%
# next component will explain a littile less and so on
#
# so now we will try to get these components
#
# so we will pick the first components it contain 40% information
# then we pick another componnet and so on
#
# s0 first 2 component will be able to explain 50% of the information
#
# s0 first 3 component will be able to explain 60% of the information
#
# s0 first 4 component will be able to explain 70% of the information
# .
# .
# .
# .
#
# s0 first 7 component will be able to explain more than 90% of the information
#
# which is exactly what we want
#
# so we will take those 7 component out of 20 componnet and now we ahve captured the information which was provided by 100 columns earlier
# after transformation and selecting these principal components , we have reduced the number of columns from 100 to 7
#
# we have only one drawback that these columns will not have any label associated with it  , so we will not get column name after transformation
#
# earlier we have column names like age , salry , number of children etc but now we have those information but not labels
# now all those details age, salry etc somehow distributed between these 7 components
#
# we have those information but we don't know how to represent that

# %% [markdown]
# ![40.JPG](attachment:40.JPG)

# %% [markdown]
# ![41.JPG](attachment:41.JPG)

# %% [markdown]
# ![42.JPG](attachment:42.JPG)

# %% [markdown]
# ![43.JPG](attachment:43.JPG)
