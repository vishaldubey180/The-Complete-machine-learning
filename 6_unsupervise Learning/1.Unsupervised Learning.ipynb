# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# In case of Unsupervise learning we do not provide output data we only provide input data

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %% [markdown]
# So in UL we will give sevearl input data and based on this input data the machine will try to find out different pattern and seggreagte these diffrenet elements into diffrenet fruits it will just group them together , it will not really no if this is bananna or apple
#
# so it will not know the information it will only try to find out the pattern present in the data

# %% [markdown]
# ![3.JPG](attachment:3.JPG)

# %% [markdown]
# Why do we need unsupervised learning??
#
# 1. To create more focused marketing campaigns
#
# lets say we have new tea product coming out and we want o find out which people is actually intrested in tea product so for that we will have to find out diffrenet groups of people and their liking and we have to segregate people on the basis of their likings and based on their likings and based on their daily activity we can say that yes these kind of people will be intrested in tea or these kind of people will not be intrested in tea
# so we will find out diffreent pattern or diffrenet characterstics about the people
#
# 2. Find cluster of data pattern
#
# 3. Group similar items
#
# 4. product categorization
#
# 5. Anomly detection
#
# Let's say we have daily transcation and we have monthly transcation of 10k
# if somehow there is month in which i have made 100k transcation then it will craete red flag for my bank and my bank will immediately communicate to me that there is a very high amount of transaction which has been made
# so this amount will actually be varying for every person based on their normal transcation
#
# hence anomalies detection is the process of finding out some diffreent pattren or something which is diffrent from the normal behaviour
#
# 6. dimensionality reduction

# %% [markdown]
# Let's see some more importanyt thing which we need to take care while working with unsupervise learning

# %% [markdown]
# 1.scaling

# %% [markdown]
# ![4.JPG](attachment:4.JPG)

# %% [markdown]
# Scaling of data is also required in svm and knn because there again , the information is being delt with in term of distance
#
# so it is important to scale the data in knn, svm and all the distance based algorithm which are majorly present in unsupervised learning
#
#
# In digram we have unnormalise house details
#
# so we have data how much years old house and how much number of rooms
# we can see that data is horizontally distributed
#
# we can not find out the number of rooms as it is very difficult to find out
#
# but if we normalize the data then range of data will be changed
# the value of years of houses is changed and the value for number of rooms is also changed from 0-1
#
# Now we can see clearly impact of data after scaling

# %% [markdown]
# ![5.JPG](attachment:5.JPG)

# %% [markdown]
# first digram is actual data
#
# normalization will try to bring it 0-1 in both x and y axis
#
# while in standarization it will try to bring the data between -1 to 1
#
# sow e can see that the distribution of the data and based on distribution of data we can choose either we have to with standarization or normalization

# %% [markdown]
# ![6.JPG](attachment:6.JPG)

# %% [markdown]
# here we have an original data
#
# where we have different column with diffreent ranges
#
# when we normalize the data we can see that all the datapoints bring got to the same range and impact will not get diminshed

# %% [markdown]
# 2. Clustering

# %% [markdown]
# ![7.JPG](attachment:7.JPG)

# %% [raw]
# Clustering is a process to create groups based on similarity measures
#
# similarity measure is diffrenet criteria on the basis of which these groups are similar
#
# so let's say we have some fruits and vegetables and we want to find out similarity measure , the similarity measure would be the taste of the item which we have , or it is juicy or not etc
#
# let's say we are deciding on taste then apple and pottato will bought into same categories
#
#
# so principal of maximisation of intracluster similarity and minimization of intercluster similarity
#
# so here we are grouping the items together
#
# we will do this by maximize the distance between two different cluster and will try to minimize the distance between the datapoints which are belonging to same cluster

# %% [markdown]
# ![8.JPG](attachment:8.JPG)

# %% [markdown]
# So here we have some datapoints
#
# we can see that there are two groups present so here we can easily seperate this data into group1 and group2
#
# but now let's say if we want to have more number of groups , let's say we want 4 groups
#
# so the farthest ones will again be subdivide into 4 cluster
#
# and again if we start to find out more clster then it will be divided into subcluster until no clustr can be made

# %% [markdown]
# ![9.JPG](attachment:9.JPG)

# %% [markdown]
# ## diffreent type of distance finding

# %% [markdown]
# ![10.JPG](attachment:10.JPG)

# %% [markdown]
# 1. single link
#
# sungle link is to find out the distance bewteen closest point
#
# 2. Complete link
#
# if we want to find out the distance between the farthest point then it is called a complete link
#
# 3. Average-link
#
# if we want o find out the distance between average of all the pairs
#
# 4. Centroid distance
#
# when we want to find out distance from centroid
