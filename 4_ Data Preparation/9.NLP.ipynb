# %% [markdown]
# # Natural Language processing

# %% [markdown]
# - till now we have discussed about tabular structured data this type of data contains different columns , these columns contains catagorical,numerical and ordinal values and alond with that we used to have either a target  value which was a class form or numerical form which would help finding out a  regression problem
# - let's say we don't have such data with column
# - we have data which contain a lot of text present in it now we can not convert this lot of text into different column
# - and even if we are able to convert into different column the machine would not be able to find out the meaning of different words in text
# - so how to handle this data and how we can transform this data such that we can apply models on top of that
# - this is done by natural language processing
# - how we will process this entire text is what we would learn next

# %% [markdown]
# ![23.JPG](attachment:23.JPG)

# %% [markdown]
# - Nlp can be used to i prove the efficiency of documentation process
# -  to improve the accuracy of documentation process
# - to identify the most pertinent information from large databases
# - let's say we work in an organization who want to find out which customer is satisfied with the services and what number of customer are not satisfied with customer
# - let's say we want to look out twitter
# - so what we do is we take complete collection of the tweets from our users and try to find out which user has tweeted something  positive about the organisation and which user has twitted negative about the organisation
# - And then after that from the negative feedback , what we try to do is we can take out those specific keywords which were related to some products or services which our organization was proviing
# - let's say we make shoes and shirts so we can find out the negative commnets from the tweets
# - now let's say we found out that all the shoes have some negative tweets, so from that particular text we can extract those specific words , which would target on what is actually wrong with our shoes
# - this is what we can achieve from NLP

# %% [markdown]
# ![24.JPG](attachment:24.JPG)

# %% [markdown]
# ### Text mining
#
# - Text mining refers to the process od deriving high quality information from the text
# - The overarching goal is essentially to turn the text into data  for analysis via application of nlp
# - so instead of having structural data we now have textual data
# - Now our task is here to convert textual data into structural data

# %% [markdown]
# ![25.JPG](attachment:25.JPG)

# %% [markdown]
# ![26.JPG](attachment:26.JPG)

# %% [markdown]
# **Tokenization**::
#    - tokenization is the process of converting text into tokens
#    - let's say we have sentance "my house is  very beautiful"
#    - so out of these sentance we have to create several token
#    - so the tokens would be
#       - my
#       - house
#       - is
#       - very
#       - beautiful
#    - so each and every word in this santance is token
#    - so tokens are the words or entities present in the text
#    - different text obj could be a sentance , a pharse, a word or an entire article
#    - what we do in nlp is the segment the word or sentances into different tokens
#    - and after that we preprocess the text
#    - the pre=processing of this text incudes the removal of stopwords then stemming or lemmatization
#    - And finally converting these text into different vecors

# %% [markdown]
# - let's ay we have this example
# ![27.JPG](attachment:27.JPG)

# %% [markdown]
# - let's sayw e have this particular text
# - here we have several quotes , commas and full stops  present here
# - these sentances also have words which does not really are important ex: in are, the
# - these are the word which we don't need
# - so the first step is to convert these text and then remove those unwanted words so we remove those stopwords and punctuations
# - after remoing

# %% [markdown]
# ![28.JPG](attachment:28.JPG)

# %%
# first we applied stemming

# %% [markdown]
# ![29.JPG](attachment:29.JPG)

# %% [markdown]
# - Basically whatw e do in stemming is we remove the suffix from the word
# - ex1. beautiful and beautifully  now if we see the meaning from beautiful and beautifully is little different but still because the root word that is beauti is common in these both words these are stemmed to beauti
# - ex2. while the word good, beeter and best has same menaing but because they are not having teh suffix kind of a structure where same word is extended by suffix these are converted into  good, better, best only , they are not converted by stemming
# - so stemming has no impact on these kind of words who do not share a same word stem

# %% [markdown]
# ![30.JPG](attachment:30.JPG)

# %% [markdown]
# # lemmatization

# %% [markdown]
# ![31.JPG](attachment:31.JPG)

# %% [markdown]
# ![32.JPG](attachment:32.JPG)

# %% [markdown]
# ![33.JPG](attachment:33.JPG)

# %% [markdown]
# - After we applied stemming or lemmetiztion what we do is we convert these words into vector form
# - there are two ways of doing this
#    - converting it into count features
#    - Tf-Idf

# %% [markdown]
# ![34.JPG](attachment:34.JPG)

# %% [markdown]
# - So what we do in count features is we can create kind of feature or column where each word have the freq of it's occurence

# %% [markdown]
# ![35.JPG](attachment:35.JPG)

# %% [markdown]
# ![36.JPG](attachment:36.JPG)

# %% [markdown]
# - In this scenarios when we have just few words created a huge matrix
# - now if we are working with huge text then the matrix would be created be very large
# - so that is the reason why the first step we did was to remove the stopwords  and punctuation so that we could reduce the size of the matrix
# - Now another thing is when we are creating this matrix , we don;t want words to occur very frequently or the words which occur very less number of times
# - so for that instaead of creating simple countvector what we can do is we can create a TF-IDF vector
# - what it do is it try to keep only those words which are not occuring frequently
