# %% [markdown]
# # Junk property classification

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# The target column is named as junk , so we need to clasify these properties so that we get a value either 0 or one
