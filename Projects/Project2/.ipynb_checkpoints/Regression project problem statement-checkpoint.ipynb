# %% [markdown]
# # Regression Project

# %% [markdown]
# In this projectw e have data which of house
# the target here is price column and we ahve around 22k of data
# now price is continuous value so this shoud be a regression problem
#
# as we can see that there are no catagorical column so we don't need to convert anything into dummy variable

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# - So we wil find out different outliers and missing data and in case there are certain outliers or missing data then we willl try to impute value to it
#
# we can aslo create new column
#
# we don't need to improve model performances alot . if a model acuuracy at one ppoint of time is 88% using a linear model and using a random forest the accuracy change to 88.1 then it is not recomended to use random forest because we are not gaining a lot in terms of accuracy but we are increasing the complexity of the models
#
# a model which is giving us better accuracy we should choose that model

# %%
# Import libraries

# %%
import numpy as np # scientific computaion 
import pandas as pd # to deal with rows and column 
import matplotlib.pyplot as plt # visualization
import seaborn as sns # # visualization
import xgboost
import math
from __future__ import division 
from scipy.stats import pearsonr # Calculates a Pearson correlation coefficient and the p-value for testing non-correlation
from sklearn.linear_model import LinearRegression
from sklearn import cross_validation, tree, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score
# Out:
#   File "<ipython-input-5-700a881f7fe7>", line 10
#     from sklearn import cross_validation, tree, linear_model
#            ^
# SyntaxError: from __future__ imports must occur at the beginning of the file

# %%
from __future__ import division 
import numpy as np # scientific computaion 
import pandas as pd # to deal with rows and column 
import matplotlib.pyplot as plt # visualization
import seaborn as sns # # visualization
import xgboost
import math

from scipy.stats import pearsonr # Calculates a Pearson correlation coefficient and the p-value for testing non-correlation
from sklearn.linear_model import LinearRegression
from sklearn import cross_validation, tree, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-b3e181be77f6> in <module>
#       9 from scipy.stats import pearsonr # Calculates a Pearson correlation coefficient and the p-value for testing non-correlation
#      10 from sklearn.linear_model import LinearRegression
# ---> 11 from sklearn import cross_validation, tree, linear_model
#      12 from sklearn.model_selection import train_test_split
#      13 from sklearn.metrics import explained_variance_score
#
# ImportError: cannot import name 'cross_validation' from 'sklearn' (C:\Users\Admin\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\__init__.py)

# %%
from __future__ import division 
import numpy as np # scientific computaion 
import pandas as pd # to deal with rows and column 
import matplotlib.pyplot as plt # visualization
import seaborn as sns # # visualization
import xgboost
import math

from scipy.stats import pearsonr # Calculates a Pearson correlation coefficient and the p-value for testing non-correlation
from sklearn.linear_model import LinearRegression
from sklearn import tree, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score

# %% [markdown]
# cross_validation is deprecated since version 0.18. This module will be removed in 0.20.
#
# Use sklearn.model_selection.train_test_split instead.

# %% [markdown]
# # EDA

# %%
# Reading Data

# %%
data = pd.read_csv('kc_house_data.csv')

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.shape
# Out:
# (21613, 21)

# %%
# Check the number of datapoints in the dataset

# %%
len(data)
# Out:
# 21613

# %%
# Check the number of features present in the dataset

# %%
len(data.columns)
# Out:
# 21

# %%
# Check the datatypes

# %%
data.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
data.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %% [markdown]
# As we can see that we have some catagorical column let's find that
#
# **Since there are python objects in the dataset , we may have some catagoricalfeatures Let's check them**

# %%
data.select_dtypes(include=['O']).columns.tolist()
# Out:
# ['date']

# %% [markdown]
# **We have only date columns which is timestamp that we will ignore**

# %%
# Check any number of column with null values

# %%
data.isnull().any().sum()
# Out:
# 0

# %%
data.isnull().any().sum(), ' / ', len(data.columns)
# Out:
# (0, ' / ', 21)

# %%
# check number of datapoints with NAN

# %%
data.isnull().any(axis=1).sum()
# Out:
# 0

# %%
data.isnull().any(axis=1).sum(), '/', len(data)
# Out:
# (0, '/', 21613)

# %%
data.isnull()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21608  False  False  False     False      False        False     False
# 21609  False  False  False     False      False        False     False
# 21610  False  False  False     False      False        False     False
# 21611  False  False  False     False      False        False     False
# 21612  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# **The dataset is pretty much structured and doesn't have any NAN values . So we can jump into finding correlations between the features and the target variable**

# %% [markdown]
# # 2. Correlation between features and target

# %%
features = data[:, 3:].columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-fcd9bd36c689> in <module>
# ----> 1 features = data[:, 3:].columns.tolist()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#    2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# ...

# %%
features = data.iloc[:, 3:].columns.tolist()

# %%
target = data.iloc[:,2].name

# %%
features
# Out:
# ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
target
# Out:
# 'price'

# %%
correlations = {}
for f in features:
    data_temp = data[[f,target]]
    x1 = data_temp[f].values
    x2 = data_temp[target].values
    key = f + ' vs ' + target
    correlations[key] = pearsonr(x1,x2)[0]

# %%
data_correlations = pd.DataFrame(correlations, index=['Value']).T
data_correlations.loc[data_correlations['Value'].abs().sort_values(ascending=False).index]
# Out:
#                            Value
# sqft_living vs price    0.702035
# grade vs price          0.667434
# sqft_above vs price     0.605567
# sqft_living15 vs price  0.585379
# bathrooms vs price      0.525138
# view vs price           0.397293
# sqft_basement vs price  0.323816
# bedrooms vs price       0.308350
# lat vs price            0.307003
# waterfront vs price     0.266369
# floors vs price         0.256794
# yr_renovated vs price   0.126434
# sqft_lot vs price       0.089661
# sqft_lot15 vs price     0.082447
# yr_built vs price       0.054012
# zipcode vs price       -0.053203
# condition vs price      0.036362
# long vs price           0.021626

# %% [markdown]
# So here what we are doing we are getting feature value and target value
#
# and we are finding out the correlations
#
# we are creating blank correlation and putting out pearson correlation into it and comparing each of the values with the target values
# so we are comparing all the values with the target values to find the correlation
#
# next we are converting all the data of correlation into dataframe
#
# and for each location we are getting absolute values and sorting that values

# %% [markdown]
# - We can see that the top 5 features are the most correlated features with the target "price"
# - Let's plot the best 2 regressors jointly

# %%
y = data.loc[:,['sqft_living','grade',target]].sort_values(target, ascending=True).values
x = np.arange(y.shape[0])

# %% [markdown]
# So we are taking x and y variable
#
# y contain sqft_living and grade whch is highly corelated , top 2 column

# %%
# %matplotlib inline
plt.subplot(3,1,1)
plt.plot(x,y[:,0])
plt.title('Sqft and Grade vs Price')
plt.ylabel('Sqft')

plt.subplot(3,1,2)
plt.plot(x,y[:,1])
plt.ylabel('Grade')

plt.subplot(3,1,3)
plt.plot(x,y[:,2],'r')
plt.ylabel("Price")

plt.show()

# %% [markdown]
# We can see both are similar graph

# %% [markdown]
# # 3. Predicting House Sales Prices

# %%
# Train a simple linear regression model
regr = linear_model.LinearRegression()
new_data = data[['sqft_living','grade', 'sqft_above', 'sqft_living15','bathrooms','view','sqft_basement','lat','waterfront','yr_built','bedrooms']]

# %%
X = new_data.values
y = data.price.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size=0.2)

# %%
regr.fit(X_train, y_train)
print(regr.predict(X_test))
# Out:
# [ 878213.6424202   496728.93968076  313525.35478625 ...  420570.21014939
#  1335442.25029642  560126.88016952]

# %%
regr.score(X_test,y_test)
# Out:
# 0.6758411440225531

# %% [markdown]
# - Prediction score is about 70 which is not really optimal
# - Now we will improve the score

# %%
# Calculate the Root Mean Squared Error
print("RMSE: %.2f"
      % math.sqrt(np.mean((regr.predict(X_test) - y_test) ** 2)))
# Out:
# RMSE: 214732.31

# %%
# Let's try XGboost algorithm to see if we can get better results
xgb = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)

# %%
traindf, testdf = train_test_split(X_train, test_size = 0.3)
xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.08, max_delta_step=0, max_depth=7,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=0.75,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
predictions = xgb.predict(X_test)
print(explained_variance_score(predictions,y_test))
# Out:
# 0.8025952292201336

# %% [markdown]
# - Our accuracy is changing between 79%-84%. I think it is close to an optimal solution.
